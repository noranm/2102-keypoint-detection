# %% [markdown]
# # 1. 준비
# ## 1.1. 라이브러리 로드

# %%
import os
from typing import Tuple, List, Sequence, Callable

import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch

from torch import nn, Tensor
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from torchvision.models import mobilenet_v2
from torchvision.models import resnet101

# from torchvision.models.detection import keypointrcnn_resnet50_fpn
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import MultiScaleRoIAlign
from torchvision.models.detection import KeypointRCNN
from torch.utils.data.sampler import SubsetRandomSampler

# !pip install -U git+https://github.com/albu/albumentations
import albumentations as A
from albumentations.pytorch import ToTensorV2
# Out:
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-j0anvkdm
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-j0anvkdm
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from albumentations==0.5.2) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from albumentations==0.5.2) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from albumentations==0.5.2) (0.16.2)
# Collecting imgaug>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/66/b1/af3142c4a85cba6da9f4ebb5ff4e21e2616309552caca5e8acefe9840622/imgaug-0.4.0-py2.py3-none-any.whl (948kB)
#      |████████████████████████████████| 952kB 6.0MB/s
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.7/dist-packages (from albumentations==0.5.2) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from albumentations==0.5.2) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (2.4.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (7.0.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (1.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (3.2.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (2.5)
# Requirement already satisfied, skipping upgrade: Shapely in /usr/local/lib/python3.7/dist-packages (from imgaug>=0.4.0->albumentations==0.5.2) (1.7.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from imgaug>=0.4.0->albumentations==0.5.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==0.5.2) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==0.5.2) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==0.5.2) (1.3.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==0.5.2) (2.8.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.0->scikit-image>=0.16.1->albumentations==0.5.2) (4.4.2)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.5.2-cp37-none-any.whl size=88322 sha256=547a5aa8ebf6ec21f83d5b7b4c83382ae6289d53fa556837235fc434aafffca2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jbjfyto7/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# Installing collected packages: imgaug, albumentations
#   Found existing installation: imgaug 0.2.9
#     Uninstalling imgaug-0.2.9:
#       Successfully uninstalled imgaug-0.2.9
#   Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# Successfully installed albumentations-0.5.2 imgaug-0.4.0

# %% [markdown]
# ## 1.2 Google Drives 연결

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

import os
os.chdir('/content/gdrive/Shared drives/keypoint/') # MyDrive/motion_keypoint/... (공유 풀더 위치)
# Out:
# Mounted at /content/gdrive/

# %%
# draw_keypoints
# 기존 함수에서 boxpoints 추가함.
# boxpoints = [] 로 비워두면 자동으로 keypoints 값 이용해서 min, max 값 생성..
# test data 의 경우 채워두면 predicted box points 사용 

edges = [
    (0, 1), (0, 2), (2, 4), (1, 3), (6, 8), (8, 10), (9, 18),
    (10, 19), (5, 7), (7, 9), (11, 13), (13, 15), (12, 14),
    (14, 16), (15, 22), (16, 23), (20, 21), (5, 6), (5, 11),
    (6, 12), (11, 12), (17, 20), (20, 21), 
]

df2 = pd.read_csv('./data/mpii_cooc_label.csv')
df = pd.read_csv('./data/train_df2.csv')
keypoint_names = df.columns[1:].tolist()

def draw_keypoints(image: np.ndarray, keypoints: np.ndarray, boxpoints, edges: List[Tuple[int, int]]) -> None:
  """
  Args:
  image (ndarray): [H, W, C]
  keypoints (ndarray): [N, 3]
  edges (List(Tuple(int, int))):
  """
  np.random.seed(42)
  colors = {k: tuple(map(int, np.random.randint(0, 255, 3))) for k in range(24)}
  
  keypoints=keypoints.astype(np.int64)

  if len(boxpoints) == 0 :
    x1, y1 = min(keypoints[:, 0]), min(keypoints[:, 1])
    x2, y2 = max(keypoints[:, 0]), max(keypoints[:, 1]) 
  else :
    x1 = boxpoints[0]; y1 = boxpoints[1]; 
    x2 = boxpoints[2]; y2 = boxpoints[3];

  print(x1, y1, x2, y2)
  cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), (255, 100, 91), thickness=3)

  for i, keypoint in enumerate(keypoints):
    cv2.circle(image, tuple(keypoint),
               3, colors.get(i), thickness=3, lineType=cv2.FILLED)
    
    cv2.putText(image, f'{i}: {keypoint_names[i]}',
                tuple(keypoint),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1)
    
    for i, edge in enumerate(edges):
      cv2.line(image, tuple(keypoints[edge[0]]),
               tuple(keypoints[edge[1]]), colors.get(edge[0]), 3, lineType=cv2.LINE_AA)
    
  fig, ax = plt.subplots(dpi=200)
  ax.imshow(image)
  ax.axis('off')
  plt.show()
  # fig.savefig('example.png')

# %%
df2.head()
# Out:
#            image      nose_x  ...  left_instep  right_instep
# 0  036636184.jpg  419.813812  ...          NaN           NaN
# 1  045606998.jpg  409.908722  ...          NaN           NaN
# 2  060754485.jpg  607.660767  ...          NaN           NaN
# 3  017052412.jpg  571.060974  ...          NaN           NaN
# 4  094888554.jpg  877.375122  ...          NaN           NaN
#
# [5 rows x 68 columns]

# %%
print(df2.shape)
# Out:
# (2093, 68)

# %%
mpii_info = pd.read_csv('./data/mpii_cooc_label.csv')

# %%
motion_key = ["nose_x", "nose_y",
              "left_eye_x", "left_eye_y",
              "right_eye_x", "right_eye_y",
              "left_ear_x", "left_ear_y",
              "right_ear_x", "right_ear_y",
              "left_shoulder_x", "left_shoulder_y",

               "right_shoulder_x", "right_shoulder_y",
               "left_elbow_x", "left_elbow_y",
               "right_elbow_x", "right_elbow_y",
               "left_wrist_x", "left_wrist_y",
               "right_wrist_x", "right_wrist_y",
               "left_hip_x", "left_hip_y",
               "right_hip_x", "right_hip_y",
               "left_knee_x", "left_knee_y",
               "right_knee_x", "right_knee_y",
               "left_ankle_x", "left_ankle_y",
               "right_ankle_x", "right_ankle_y",
               "neck_x", "neck_y",
               "left_palm_x", "left_palm_y",
               "right_palm_x", "right_palm_y",
               "spine2(back)_x", "spine2(back)_y",
               "spine1(waist)_x", "spine1(waist)_y",
               "left_instep_x", "left_instep_y",
               "right_instep_x", "right_instep_y"]

print(len(motion_key))
             
# left_sholuder
motion_vis = ["left_shoulde", "right_shoulder", "left_elbow", "right_elbow", "left_wrist", "right_wrist", "left_hip", "right_hip", "left_knee", "right_knee", "left_ankle", "right_ankle", "neck", "left_palm", "right_palm", "spine2(back)", "spine1(waist)", "left_instep", "right_instep"]

mpii_info['left_palm'] = mpii_info['left_wrist']
mpii_info['left_palm_x'] = mpii_info['left_wrist_x']
mpii_info['left_palm_y'] = mpii_info['left_wrist_y']

mpii_info['right_palm'] = mpii_info['right_wrist']
mpii_info['right_palm_x'] = mpii_info['right_wrist_x']
mpii_info['right_palm_y'] = mpii_info['right_wrist_y']

mpii_info['left_instep'] = mpii_info['left_ankle']
mpii_info['left_instep_x'] = mpii_info['left_ankle_x']
mpii_info['left_instep_y'] = mpii_info['left_ankle_y']

mpii_info['right_instep'] = mpii_info['right_ankle']
mpii_info['right_instep_x'] = mpii_info['right_ankle_x']
mpii_info['right_instep_y'] = mpii_info['right_ankle_y']

print(mpii_info.shape)
print(mpii_info[motion_key].shape)
print(mpii_info[motion_vis].shape)
# Out:
# 48
# (2093, 68)
# (2093, 48)
# (2093, 19)

# %%
mpii_info.head()
# Out:
#            image      nose_x  ...  left_instep  right_instep
# 0  036636184.jpg  419.813812  ...          NaN           NaN
# 1  045606998.jpg  409.908722  ...          NaN           NaN
# 2  060754485.jpg  607.660767  ...          NaN           NaN
# 3  017052412.jpg  571.060974  ...          NaN           NaN
# 4  094888554.jpg  877.375122  ...          NaN           NaN
#
# [5 rows x 68 columns]

# %%
# cut off 참고 : # https://github.com/uoguelph-mlrg/Cutout/blob/master/util/cutout.py
# p=0.5 의 확률로 cutout image를 생성함 / 패치 크기는 150x150 으로 고정
class MotionDataset(Dataset):
  def __init__(self, label_df, transforms=None) :
      self.df = label_df
      self.transforms = transforms
  
  def __len__(self) -> int:
    return self.df.shape[0]
    
  def __getitem__(self,index: int) -> Tuple[Tensor]:
#    print(index)
    image_dir = self.df.iloc[index,]['path']
    image_id = self.df.iloc[index,]['image']
    data_type = self.df.iloc[index,]['type']
    
    labels = np.array([1]) 
    keypoints = self.df.iloc[index, ][motion_key].values.reshape(-1, 2).astype(np.int64)

    x1, y1 = min(keypoints[:, 0]), min(keypoints[:, 1])
    x2, y2 = max(keypoints[:, 0]), max(keypoints[:, 1])
    boxes = np.array([[x1, y1, x2, y2]], dtype=np.int64)
    
    image = cv2.imread(os.path.join(image_dir, image_id), cv2.COLOR_BGR2RGB)
    #if data_type == "mpii" : 
    #  visible = self.df.iloc[index, ][motion_vis].values.reshape(19,1).astype(np.int64)
    #else : 
    #  visible = np.ones((19, 1))
    visible = np.ones((24, 1))
    
    # keypoints-aware occlusion p=0.5
    cutout = np.random.randint(0,2)
    if cutout == 1:
      h = image.shape[0]
      w = image.shape[1]

      #item = np.random.randint(0,19)
      item = np.random.randint(0,24)
      initx, inity = keypoints[item]
      size = np.random.randint(200, 300)

      image = cv2.rectangle(image, (initx-size, inity-size), (initx+size, inity+size), (0,0,0), -1)

      for i, keypoint in enumerate(keypoints):
        invis_check = sum([initx, inity-size] < keypoint) + sum(keypoint < [initx+size, inity])
        if invis_check == 4:
          visible[i]=0

    targets ={
        'image': image,
        'bboxes': boxes,
        'labels': labels,
        'keypoints': keypoints
    }
    
    if self.transforms is not None:
      targets = self.transforms(**targets)
      
    image = targets['image']
    image = image / 255.0

    targets = {
        'labels': torch.as_tensor(targets['labels'], dtype=torch.int64),
        'boxes': torch.as_tensor(targets['bboxes'], dtype=torch.float32),
        'keypoints': torch.as_tensor(
                np.concatenate([targets['keypoints'], visible], axis=1)[np.newaxis], dtype=torch.float32 )
        }

    return image, targets

# %%
def check_bbox(bbox):
    """Check if bbox boundaries are in range 0, 1 and minimums are lesser then maximums"""
    for name, value in zip(["x_min", "y_min", "x_max", "y_max"], bbox[:4]):
        if not 0 <= value <= 1:
          bbox=list(bbox)
          for i in range(4):
            if (bbox[i]<0) :
              bbox[i]=0.00001
            elif (bbox[i]>1) :
              bbox[i]=0.99999
          bbox=tuple(bbox)
   #end of block
    x_min, y_min, x_max, y_max = bbox[:4]
    if x_max <= x_min:
        raise ValueError("x_max is less than or equal to x_min for bbox {bbox}.".format(bbox=bbox))
    if y_max <= y_min:
        raise ValueError("y_max is less than or equal to y_min for bbox {bbox}.".format(bbox=bbox))

A.bbox_utils.check_bbox = check_bbox

# %%
# https://github.com/aleju/imgaug
# https://imgaug.readthedocs.io/en/latest/source/overview/blur.html#gaussianblur
transform1 = A.Compose([A.Resize(800, 1333), 
                       A.Rotate(limit=45, p=1.0),
                       A.OneOf([A.MedianBlur(p=1.0),
                                A.ImageCompression(p=1.0),
                       ],p=0.5),
#                       A.VerticalFlip(p=0.5),
                       A.RandomScale(scale_limit=0.25, p=1.0),
                       ToTensorV2(),
                       ],
                      bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']),
                      keypoint_params=A.KeypointParams(format='xy', remove_invisible=False))

transform_val = A.Compose([ToTensorV2(),
                       ],
                      bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']),
                      keypoint_params=A.KeypointParams(format='xy', remove_invisible=False))

# %%
def collate_fn(batch: torch.Tensor) -> Tuple:
    return tuple(zip(*batch))

train_path = './data/train_imgs/'
train_df = pd.read_csv('./data/relabel_all_df.csv')
train_df = pd.read_csv('./data/train_df2.csv')
train_df['path'] = train_path
train_df['type'] = "dacon"

mpii_path = './data/external_labeled/exter_imgs/images/'
mpii_info['path'] = mpii_path
mpii_info['type'] = "mpii"

train_all = pd.concat([train_df, mpii_info], ignore_index=True)

# %%
# R-CNN
def get_model() -> nn.Module:
    mode = resnet101(pretrained=True)
    backbone = nn.Sequential(*(list(nn.Module.children(mode))[0:8]))
    backbone.out_channels = 2048
    
    roi_pooler = MultiScaleRoIAlign(
        featmap_names=['0'],
        output_size=7,
        sampling_ratio=2
    )

    anchor_generator = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                   aspect_ratios=((0.5, 1.0, 2.0),))
    
    keypoint_roi_pooler = MultiScaleRoIAlign(
        featmap_names=['0'],
        output_size=14,
        sampling_ratio=2
    )

    model = KeypointRCNN(
        backbone, 
        num_classes=2,
        num_keypoints=24,
        box_roi_pool=roi_pooler,
        keypoint_roi_pool=keypoint_roi_pooler,
        rpn_anchor_generator=anchor_generator
    )

    return model

# %%
import random
from tqdm import tqdm
from sklearn.model_selection import KFold
def seed_everything(seed):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# # FOLD 5

# %%
# 5-CV 추가
# 참고 : https://dacon.io/competitions/official/235697/codeshare/2446?page=1&dtype=recent
num_epochs = 30
SEED = 42
lam=2**(-20)
device='cuda:0'

# cross validation을 적용하기 위해 KFold 생성
kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)

# dirty_mnist_answer에서 train_idx와 val_idx를 생성
#best_models = [] # 폴드별로 가장 validation acc가 높은 모델 저장

for fold_index, (trn_idx, val_idx) in enumerate(kfold.split( train_all ),1):
    if fold_index == 5 :
      break

print(trn_idx)
print(val_idx)
# Out:
# [   0    1    2 ... 6184 6185 6186]
# [   3    4    5 ... 6173 6175 6178]

# %%
EARLY_STOPPING_EPOCH = 4

# %%
# for fold_index, (trn_idx, val_idx) in enumerate(kfold.split( train_all ),1):

seed_everything(SEED)
print(f' == fold: {fold_index} == ')

# cuda cache 초기화
torch.cuda.empty_cache()

#train fold, validation fold 분할
trainset = train_all.iloc[trn_idx]
validset  = train_all.iloc[val_idx]

#Dataset 정의
train_data = MotionDataset(label_df=trainset, transforms=transform1)
valid_data = MotionDataset(label_df=validset, transforms=transform_val)

#DataLoader 정의
train_loader = DataLoader(train_data, batch_size=2, shuffle=True, num_workers=2, collate_fn=collate_fn)
valid_loader = DataLoader(valid_data, batch_size=2, shuffle=True, num_workers=2, collate_fn=collate_fn)

# 모델 선언
model = get_model()
model.to(device)# gpu에 모델 할당

optimizer = optim.Adam(model.parameters(), lr=1e-4)
lr_sched = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.1)

valid_early_stop = 0
valid_best_loss = float('inf')

for epoch in range(num_epochs):  
  model.train()
  for i, (images, targets) in enumerate(train_loader):
    images = list(image.to(device) for image in images)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    
    optimizer.zero_grad()
    model.train()
    losses = model(images, targets)
    loss = sum(loss for loss in losses.values())
    
    L2=0
    for param in model.parameters():
      L2 += torch.norm(param,p=2)
      loss = loss + lam * L2

    loss.backward()
    optimizer.step()

    if (i+1) % 20 == 0:
      print(f'| epoch: {epoch} | Train loss: {loss.item():.4f}', end=' | ')
      for k, v in losses.items():
        print(f'{k[5:]}: {v.item():.4f}', end=' | ')
      print()
  
  # Learning rate 조절
  lr_sched.step()

  if epoch < 1 : 
    continue

  valid_loss_list = []
  for i, (images, targets) in enumerate(valid_loader):
    optimizer.zero_grad()
    images = list(image.to(device) for image in images)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
      
    with torch.no_grad():
      losses  = model(images, targets)
      loss = sum(loss for loss in losses.values())

      valid_loss_list.append(losses['loss_keypoint'])

    if (i+1) % 20 == 0:
      print(f'| epoch: {epoch} | Valid loss: {loss.item():.4f}', end=' | ')
      for k, v in losses.items():
        print(f'{k[5:]}: {v.item():.4f}', end=' | ')
      print()

  val_mean_loss = np.mean(valid_loss_list, dtype="float64")
  print(f' > VALIDATION SET LOSS MEAN : {val_mean_loss : .4f}')
  
  # 모델 저장
  # 성능 변화 없는 에폭 3번 반복 -> Early stopping
  if val_mean_loss  < valid_best_loss :
    best_model = model
    MODEL = f"resnet101_{SEED}"
    # 경로 설정 필요
    path = f"./model/5CV/SEED_{SEED}/"
    try: 
      os.mkdir(path)
    except:
      None 
    torch.save(best_model.state_dict(), f'{path}fold{fold_index}]_{MODEL}_{val_mean_loss:2.4f}_epoch_{epoch}.pth')

  # early stopping    
  if val_mean_loss < valid_best_loss:
    valid_best_loss = val_mean_loss
    valid_early_stop = 0
  else:
    valid_early_stop += 1
    if valid_early_stop >= EARLY_STOPPING_EPOCH:
      print("EARLY_STOPPING!!")
      break


# 폴드별로 가장 좋은 모델 저장
# best_models.append(best_model)
# Out:
#  == fold: 5 ==
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# HBox(children=(FloatProgress(value=0.0, max=178728960.0), HTML(value='')))
# | epoch: 0 | Train loss: 7.7522 | classifier: 0.0833 | box_reg: 0.0342 | keypoint: 7.3721 | objectness: 0.0556 | rpn_box_reg: 0.0183 |
# | epoch: 0 | Train loss: 7.6933 | classifier: 0.1397 | box_reg: 0.1008 | keypoint: 7.2019 | objectness: 0.0378 | rpn_box_reg: 0.0244 |
# | epoch: 0 | Train loss: 8.4481 | classifier: 0.1027 | box_reg: 0.1092 | keypoint: 7.9140 | objectness: 0.0719 | rpn_box_reg: 0.0615 |
# | epoch: 0 | Train loss: 7.2843 | classifier: 0.0920 | box_reg: 0.0723 | keypoint: 6.8478 | objectness: 0.0487 | rpn_box_reg: 0.0346 |
# | epoch: 0 | Train loss: 7.6419 | classifier: 0.0937 | box_reg: 0.1408 | keypoint: 7.1843 | objectness: 0.0271 | rpn_box_reg: 0.0069 |
# | epoch: 0 | Train loss: 7.8492 | classifier: 0.1049 | box_reg: 0.1090 | keypoint: 7.3875 | objectness: 0.0425 | rpn_box_reg: 0.0162 |
# | epoch: 0 | Train loss: 7.3157 | classifier: 0.1200 | box_reg: 0.1146 | keypoint: 6.8115 | objectness: 0.0523 | rpn_box_reg: 0.0282 |
# | epoch: 0 | Train loss: 8.3739 | classifier: 0.0883 | box_reg: 0.0598 | keypoint: 7.9557 | objectness: 0.0648 | rpn_box_reg: 0.0161 |
# | epoch: 0 | Train loss: 9.5876 | classifier: 0.1366 | box_reg: 0.1557 | keypoint: 9.0187 | objectness: 0.0722 | rpn_box_reg: 0.0153 |
# | epoch: 0 | Train loss: 7.4762 | classifier: 0.0976 | box_reg: 0.1198 | keypoint: 7.0032 | objectness: 0.0494 | rpn_box_reg: 0.0169 |
# | epoch: 0 | Train loss: 7.3803 | classifier: 0.1033 | box_reg: 0.1212 | keypoint: 6.8843 | objectness: 0.0499 | rpn_box_reg: 0.0321 |
# | epoch: 0 | Train loss: 8.4661 | classifier: 0.1967 | box_reg: 0.1813 | keypoint: 7.5853 | objectness: 0.2219 | rpn_box_reg: 0.0914 |
# | epoch: 0 | Train loss: 7.8478 | classifier: 0.1467 | box_reg: 0.1539 | keypoint: 7.2346 | objectness: 0.0909 | rpn_box_reg: 0.0321 |
# | epoch: 0 | Train loss: 7.6019 | classifier: 0.0928 | box_reg: 0.0751 | keypoint: 7.1870 | objectness: 0.0501 | rpn_box_reg: 0.0073 |
# | epoch: 0 | Train loss: 7.8794 | classifier: 0.1590 | box_reg: 0.1660 | keypoint: 7.3145 | objectness: 0.0480 | rpn_box_reg: 0.0023 |
# | epoch: 0 | Train loss: 7.2979 | classifier: 0.0711 | box_reg: 0.0916 | keypoint: 6.8995 | objectness: 0.0377 | rpn_box_reg: 0.0082 |
# | epoch: 0 | Train loss: 6.7885 | classifier: 0.0960 | box_reg: 0.1250 | keypoint: 6.2240 | objectness: 0.0715 | rpn_box_reg: 0.0823 |
# | epoch: 0 | Train loss: 8.0263 | classifier: 0.1023 | box_reg: 0.0866 | keypoint: 7.5150 | objectness: 0.0843 | rpn_box_reg: 0.0484 |
# | epoch: 0 | Train loss: 8.3725 | classifier: 0.1903 | box_reg: 0.1663 | keypoint: 7.7482 | objectness: 0.0483 | rpn_box_reg: 0.0295 |
# | epoch: 0 | Train loss: 6.8159 | classifier: 0.0590 | box_reg: 0.0525 | keypoint: 6.4401 | objectness: 0.0670 | rpn_box_reg: 0.0074 |
# | epoch: 0 | Train loss: 8.8072 | classifier: 0.1365 | box_reg: 0.1013 | keypoint: 8.3130 | objectness: 0.0428 | rpn_box_reg: 0.0237 |
# | epoch: 0 | Train loss: 8.7358 | classifier: 0.1127 | box_reg: 0.1692 | keypoint: 8.1507 | objectness: 0.0484 | rpn_box_reg: 0.0647 |
# | epoch: 0 | Train loss: 6.4381 | classifier: 0.0686 | box_reg: 0.0944 | keypoint: 6.0606 | objectness: 0.0222 | rpn_box_reg: 0.0022 |
# | epoch: 0 | Train loss: 6.3926 | classifier: 0.1181 | box_reg: 0.1659 | keypoint: 5.8600 | objectness: 0.0438 | rpn_box_reg: 0.0145 |
# | epoch: 0 | Train loss: 6.2991 | classifier: 0.0869 | box_reg: 0.1020 | keypoint: 5.8735 | objectness: 0.0399 | rpn_box_reg: 0.0066 |
# | epoch: 0 | Train loss: 5.6582 | classifier: 0.0845 | box_reg: 0.0756 | keypoint: 5.2867 | objectness: 0.0198 | rpn_box_reg: 0.0013 |
# | epoch: 0 | Train loss: 6.4485 | classifier: 0.0948 | box_reg: 0.0736 | keypoint: 6.0644 | objectness: 0.0147 | rpn_box_reg: 0.0106 |
# | epoch: 0 | Train loss: 6.5709 | classifier: 0.0635 | box_reg: 0.0768 | keypoint: 6.2063 | objectness: 0.0320 | rpn_box_reg: 0.0019 |
# | epoch: 0 | Train loss: 7.2948 | classifier: 0.1069 | box_reg: 0.1612 | keypoint: 6.7929 | objectness: 0.0140 | rpn_box_reg: 0.0294 |
# | epoch: 0 | Train loss: 6.4252 | classifier: 0.0729 | box_reg: 0.0949 | keypoint: 6.0023 | objectness: 0.0471 | rpn_box_reg: 0.0176 |
# | epoch: 0 | Train loss: 5.9467 | classifier: 0.0521 | box_reg: 0.0681 | keypoint: 5.5920 | objectness: 0.0252 | rpn_box_reg: 0.0188 |
# | epoch: 0 | Train loss: 6.6729 | classifier: 0.0862 | box_reg: 0.0946 | keypoint: 6.2213 | objectness: 0.0485 | rpn_box_reg: 0.0318 |
# | epoch: 0 | Train loss: 6.6552 | classifier: 0.0872 | box_reg: 0.0862 | keypoint: 6.2003 | objectness: 0.0599 | rpn_box_reg: 0.0310 |
# | epoch: 0 | Train loss: 8.1327 | classifier: 0.0980 | box_reg: 0.0990 | keypoint: 7.6794 | objectness: 0.0491 | rpn_box_reg: 0.0164 |
# | epoch: 0 | Train loss: 6.7049 | classifier: 0.0725 | box_reg: 0.0878 | keypoint: 6.3185 | objectness: 0.0286 | rpn_box_reg: 0.0068 |
# | epoch: 0 | Train loss: 5.4953 | classifier: 0.0704 | box_reg: 0.0869 | keypoint: 5.0866 | objectness: 0.0330 | rpn_box_reg: 0.0276 |
# | epoch: 0 | Train loss: 6.6209 | classifier: 0.1432 | box_reg: 0.2020 | keypoint: 6.0322 | objectness: 0.0242 | rpn_box_reg: 0.0286 |
# | epoch: 0 | Train loss: 7.0518 | classifier: 0.0839 | box_reg: 0.0888 | keypoint: 6.6182 | objectness: 0.0666 | rpn_box_reg: 0.0036 |
# | epoch: 0 | Train loss: 7.9221 | classifier: 0.1223 | box_reg: 0.1166 | keypoint: 7.4416 | objectness: 0.0470 | rpn_box_reg: 0.0038 |
# | epoch: 0 | Train loss: 5.6884 | classifier: 0.0936 | box_reg: 0.1141 | keypoint: 5.2063 | objectness: 0.0560 | rpn_box_reg: 0.0275 |
# | epoch: 0 | Train loss: 5.0797 | classifier: 0.0500 | box_reg: 0.0715 | keypoint: 4.7409 | objectness: 0.0116 | rpn_box_reg: 0.0148 |
# | epoch: 0 | Train loss: 7.6040 | classifier: 0.1125 | box_reg: 0.1315 | keypoint: 7.0700 | objectness: 0.0741 | rpn_box_reg: 0.0249 |
# | epoch: 0 | Train loss: 5.8848 | classifier: 0.1099 | box_reg: 0.1264 | keypoint: 5.3259 | objectness: 0.0926 | rpn_box_reg: 0.0389 |
# | epoch: 0 | Train loss: 5.8609 | classifier: 0.1174 | box_reg: 0.1129 | keypoint: 5.3691 | objectness: 0.0347 | rpn_box_reg: 0.0356 |
# | epoch: 0 | Train loss: 6.0734 | classifier: 0.0951 | box_reg: 0.1402 | keypoint: 5.6333 | objectness: 0.0097 | rpn_box_reg: 0.0041 |
# | epoch: 0 | Train loss: 6.9285 | classifier: 0.0987 | box_reg: 0.1254 | keypoint: 6.4757 | objectness: 0.0347 | rpn_box_reg: 0.0028 |
# | epoch: 0 | Train loss: 6.4290 | classifier: 0.1074 | box_reg: 0.1423 | keypoint: 5.9197 | objectness: 0.0543 | rpn_box_reg: 0.0141 |
# | epoch: 0 | Train loss: 5.2896 | classifier: 0.0673 | box_reg: 0.0880 | keypoint: 4.9164 | objectness: 0.0174 | rpn_box_reg: 0.0093 |
# | epoch: 0 | Train loss: 6.7897 | classifier: 0.0796 | box_reg: 0.1343 | keypoint: 6.3382 | objectness: 0.0348 | rpn_box_reg: 0.0115 |
# | epoch: 0 | Train loss: 5.5383 | classifier: 0.0857 | box_reg: 0.1112 | keypoint: 5.0787 | objectness: 0.0597 | rpn_box_reg: 0.0116 |
# | epoch: 0 | Train loss: 5.9236 | classifier: 0.0729 | box_reg: 0.1388 | keypoint: 5.4953 | objectness: 0.0132 | rpn_box_reg: 0.0121 |
# | epoch: 0 | Train loss: 8.8440 | classifier: 0.1483 | box_reg: 0.1549 | keypoint: 8.2903 | objectness: 0.0435 | rpn_box_reg: 0.0156 |
# | epoch: 0 | Train loss: 5.9057 | classifier: 0.0680 | box_reg: 0.1099 | keypoint: 5.5153 | objectness: 0.0119 | rpn_box_reg: 0.0091 |
# | epoch: 0 | Train loss: 5.7421 | classifier: 0.0744 | box_reg: 0.0697 | keypoint: 5.3555 | objectness: 0.0473 | rpn_box_reg: 0.0037 |
# | epoch: 0 | Train loss: 5.9525 | classifier: 0.1202 | box_reg: 0.1214 | keypoint: 5.5008 | objectness: 0.0161 | rpn_box_reg: 0.0024 |
# | epoch: 0 | Train loss: 5.1634 | classifier: 0.0412 | box_reg: 0.0731 | keypoint: 4.8480 | objectness: 0.0061 | rpn_box_reg: 0.0034 |
# | epoch: 0 | Train loss: 6.6185 | classifier: 0.0830 | box_reg: 0.0864 | keypoint: 6.1795 | objectness: 0.0615 | rpn_box_reg: 0.0165 |
# | epoch: 0 | Train loss: 6.0122 | classifier: 0.0637 | box_reg: 0.0848 | keypoint: 5.6254 | objectness: 0.0352 | rpn_box_reg: 0.0113 |
# | epoch: 0 | Train loss: 5.6185 | classifier: 0.1028 | box_reg: 0.1355 | keypoint: 5.1649 | objectness: 0.0120 | rpn_box_reg: 0.0115 |
# | epoch: 0 | Train loss: 5.4365 | classifier: 0.0765 | box_reg: 0.1049 | keypoint: 5.0376 | objectness: 0.0174 | rpn_box_reg: 0.0082 |
# | epoch: 0 | Train loss: 7.0525 | classifier: 0.0953 | box_reg: 0.1234 | keypoint: 6.6191 | objectness: 0.0182 | rpn_box_reg: 0.0045 |
# | epoch: 0 | Train loss: 6.0922 | classifier: 0.0865 | box_reg: 0.0862 | keypoint: 5.7100 | objectness: 0.0117 | rpn_box_reg: 0.0057 |
# | epoch: 0 | Train loss: 6.9811 | classifier: 0.0804 | box_reg: 0.1194 | keypoint: 6.5718 | objectness: 0.0163 | rpn_box_reg: 0.0012 |
# | epoch: 0 | Train loss: 8.8224 | classifier: 0.1251 | box_reg: 0.1131 | keypoint: 8.3495 | objectness: 0.0348 | rpn_box_reg: 0.0078 |
# | epoch: 0 | Train loss: 5.9171 | classifier: 0.0479 | box_reg: 0.0556 | keypoint: 5.5868 | objectness: 0.0298 | rpn_box_reg: 0.0048 |
# | epoch: 0 | Train loss: 6.9208 | classifier: 0.1339 | box_reg: 0.0938 | keypoint: 6.4498 | objectness: 0.0470 | rpn_box_reg: 0.0041 |
# | epoch: 0 | Train loss: 5.8270 | classifier: 0.0586 | box_reg: 0.0365 | keypoint: 5.5033 | objectness: 0.0314 | rpn_box_reg: 0.0049 |
# | epoch: 0 | Train loss: 6.6608 | classifier: 0.1017 | box_reg: 0.1068 | keypoint: 6.2143 | objectness: 0.0314 | rpn_box_reg: 0.0143 |
# | epoch: 0 | Train loss: 4.6643 | classifier: 0.0693 | box_reg: 0.1161 | keypoint: 4.2711 | objectness: 0.0081 | rpn_box_reg: 0.0072 |
# | epoch: 0 | Train loss: 5.7658 | classifier: 0.0619 | box_reg: 0.0678 | keypoint: 5.4278 | objectness: 0.0149 | rpn_box_reg: 0.0011 |
# | epoch: 0 | Train loss: 7.7079 | classifier: 0.1205 | box_reg: 0.1099 | keypoint: 7.1737 | objectness: 0.0855 | rpn_box_reg: 0.0259 |
# | epoch: 0 | Train loss: 5.4687 | classifier: 0.0497 | box_reg: 0.0535 | keypoint: 5.1472 | objectness: 0.0193 | rpn_box_reg: 0.0065 |
# | epoch: 0 | Train loss: 8.0203 | classifier: 0.0801 | box_reg: 0.0787 | keypoint: 7.6392 | objectness: 0.0270 | rpn_box_reg: 0.0028 |
# | epoch: 0 | Train loss: 6.7700 | classifier: 0.0643 | box_reg: 0.0628 | keypoint: 6.0672 | objectness: 0.1561 | rpn_box_reg: 0.2270 |
# | epoch: 0 | Train loss: 8.4224 | classifier: 0.2551 | box_reg: 0.2025 | keypoint: 7.6245 | objectness: 0.0937 | rpn_box_reg: 0.0541 |
# | epoch: 0 | Train loss: 5.2439 | classifier: 0.0547 | box_reg: 0.0742 | keypoint: 4.8722 | objectness: 0.0358 | rpn_box_reg: 0.0144 |
# | epoch: 0 | Train loss: 5.9335 | classifier: 0.1278 | box_reg: 0.1624 | keypoint: 5.4099 | objectness: 0.0278 | rpn_box_reg: 0.0130 |
# | epoch: 0 | Train loss: 7.3026 | classifier: 0.1481 | box_reg: 0.1765 | keypoint: 6.7329 | objectness: 0.0457 | rpn_box_reg: 0.0068 |
# | epoch: 0 | Train loss: 5.1056 | classifier: 0.0687 | box_reg: 0.0930 | keypoint: 4.7288 | objectness: 0.0139 | rpn_box_reg: 0.0085 |
# | epoch: 0 | Train loss: 7.1576 | classifier: 0.0923 | box_reg: 0.0998 | keypoint: 6.7243 | objectness: 0.0467 | rpn_box_reg: 0.0018 |
# | epoch: 0 | Train loss: 6.2075 | classifier: 0.0697 | box_reg: 0.0757 | keypoint: 5.8422 | objectness: 0.0169 | rpn_box_reg: 0.0102 |
# | epoch: 0 | Train loss: 5.8292 | classifier: 0.0570 | box_reg: 0.0725 | keypoint: 5.4944 | objectness: 0.0087 | rpn_box_reg: 0.0038 |
# | epoch: 0 | Train loss: 6.4749 | classifier: 0.0918 | box_reg: 0.1068 | keypoint: 6.0280 | objectness: 0.0285 | rpn_box_reg: 0.0269 |
# | epoch: 0 | Train loss: 7.5079 | classifier: 0.1194 | box_reg: 0.1289 | keypoint: 7.0158 | objectness: 0.0468 | rpn_box_reg: 0.0040 |
# | epoch: 0 | Train loss: 9.2423 | classifier: 0.1177 | box_reg: 0.1475 | keypoint: 8.7356 | objectness: 0.0375 | rpn_box_reg: 0.0112 |
# | epoch: 0 | Train loss: 7.9717 | classifier: 0.1234 | box_reg: 0.1074 | keypoint: 7.4364 | objectness: 0.0700 | rpn_box_reg: 0.0416 |
# | epoch: 0 | Train loss: 5.5967 | classifier: 0.0475 | box_reg: 0.0454 | keypoint: 5.2970 | objectness: 0.0116 | rpn_box_reg: 0.0023 |
# | epoch: 0 | Train loss: 6.5871 | classifier: 0.0857 | box_reg: 0.1030 | keypoint: 6.1610 | objectness: 0.0315 | rpn_box_reg: 0.0128 |
# | epoch: 0 | Train loss: 6.6756 | classifier: 0.1396 | box_reg: 0.1467 | keypoint: 6.1694 | objectness: 0.0218 | rpn_box_reg: 0.0050 |
# | epoch: 0 | Train loss: 5.9456 | classifier: 0.0451 | box_reg: 0.0749 | keypoint: 5.6176 | objectness: 0.0115 | rpn_box_reg: 0.0033 |
# | epoch: 0 | Train loss: 5.2247 | classifier: 0.0343 | box_reg: 0.0326 | keypoint: 4.9238 | objectness: 0.0376 | rpn_box_reg: 0.0032 |
# | epoch: 0 | Train loss: 7.9590 | classifier: 0.1628 | box_reg: 0.2028 | keypoint: 7.3342 | objectness: 0.0615 | rpn_box_reg: 0.0043 |
# | epoch: 0 | Train loss: 6.2128 | classifier: 0.0800 | box_reg: 0.1363 | keypoint: 5.7693 | objectness: 0.0266 | rpn_box_reg: 0.0072 |
# | epoch: 0 | Train loss: 7.8905 | classifier: 0.0858 | box_reg: 0.0771 | keypoint: 7.4999 | objectness: 0.0319 | rpn_box_reg: 0.0024 |
# | epoch: 0 | Train loss: 7.7965 | classifier: 0.1944 | box_reg: 0.2117 | keypoint: 7.1229 | objectness: 0.0617 | rpn_box_reg: 0.0123 |
# | epoch: 0 | Train loss: 7.1030 | classifier: 0.1237 | box_reg: 0.1297 | keypoint: 6.6036 | objectness: 0.0478 | rpn_box_reg: 0.0048 |
# | epoch: 0 | Train loss: 7.6108 | classifier: 0.0930 | box_reg: 0.0965 | keypoint: 7.1783 | objectness: 0.0472 | rpn_box_reg: 0.0024 |
# | epoch: 0 | Train loss: 6.5487 | classifier: 0.0965 | box_reg: 0.1141 | keypoint: 6.1221 | objectness: 0.0138 | rpn_box_reg: 0.0086 |
# | epoch: 0 | Train loss: 5.2948 | classifier: 0.0445 | box_reg: 0.0495 | keypoint: 4.9898 | objectness: 0.0153 | rpn_box_reg: 0.0020 |
# | epoch: 0 | Train loss: 6.1742 | classifier: 0.1046 | box_reg: 0.1146 | keypoint: 5.7174 | objectness: 0.0359 | rpn_box_reg: 0.0079 |
# | epoch: 0 | Train loss: 7.7211 | classifier: 0.1063 | box_reg: 0.1287 | keypoint: 7.2538 | objectness: 0.0308 | rpn_box_reg: 0.0078 |
# | epoch: 0 | Train loss: 6.3113 | classifier: 0.0965 | box_reg: 0.0959 | keypoint: 5.8888 | objectness: 0.0276 | rpn_box_reg: 0.0086 |
# | epoch: 0 | Train loss: 7.5209 | classifier: 0.0773 | box_reg: 0.0938 | keypoint: 7.1464 | objectness: 0.0084 | rpn_box_reg: 0.0013 |
# | epoch: 0 | Train loss: 6.7601 | classifier: 0.1870 | box_reg: 0.1960 | keypoint: 6.1252 | objectness: 0.0403 | rpn_box_reg: 0.0178 |
# | epoch: 0 | Train loss: 7.9229 | classifier: 0.1893 | box_reg: 0.1614 | keypoint: 7.2546 | objectness: 0.0830 | rpn_box_reg: 0.0407 |
# | epoch: 0 | Train loss: 6.3218 | classifier: 0.0648 | box_reg: 0.0821 | keypoint: 5.9387 | objectness: 0.0370 | rpn_box_reg: 0.0053 |
# | epoch: 0 | Train loss: 8.4805 | classifier: 0.1652 | box_reg: 0.1550 | keypoint: 7.9014 | objectness: 0.0548 | rpn_box_reg: 0.0102 |
# | epoch: 0 | Train loss: 5.7968 | classifier: 0.0735 | box_reg: 0.1019 | keypoint: 5.3784 | objectness: 0.0163 | rpn_box_reg: 0.0326 |
# | epoch: 0 | Train loss: 6.3650 | classifier: 0.0808 | box_reg: 0.0859 | keypoint: 5.9798 | objectness: 0.0190 | rpn_box_reg: 0.0054 |
# | epoch: 0 | Train loss: 7.0197 | classifier: 0.0835 | box_reg: 0.1127 | keypoint: 6.5650 | objectness: 0.0568 | rpn_box_reg: 0.0075 |
# | epoch: 0 | Train loss: 7.3458 | classifier: 0.1319 | box_reg: 0.0708 | keypoint: 6.9064 | objectness: 0.0379 | rpn_box_reg: 0.0047 |
# | epoch: 0 | Train loss: 6.2003 | classifier: 0.1035 | box_reg: 0.1393 | keypoint: 5.7523 | objectness: 0.0079 | rpn_box_reg: 0.0031 |
# | epoch: 0 | Train loss: 5.4301 | classifier: 0.0804 | box_reg: 0.0999 | keypoint: 5.0408 | objectness: 0.0106 | rpn_box_reg: 0.0042 |
# | epoch: 0 | Train loss: 8.2902 | classifier: 0.2315 | box_reg: 0.2390 | keypoint: 7.5048 | objectness: 0.1027 | rpn_box_reg: 0.0180 |
# | epoch: 0 | Train loss: 8.2438 | classifier: 0.1777 | box_reg: 0.0876 | keypoint: 7.6422 | objectness: 0.1259 | rpn_box_reg: 0.0161 |
# | epoch: 0 | Train loss: 5.4001 | classifier: 0.0667 | box_reg: 0.0946 | keypoint: 5.0235 | objectness: 0.0126 | rpn_box_reg: 0.0084 |
# | epoch: 0 | Train loss: 4.5376 | classifier: 0.0609 | box_reg: 0.0851 | keypoint: 4.1886 | objectness: 0.0060 | rpn_box_reg: 0.0026 |
# | epoch: 0 | Train loss: 6.7769 | classifier: 0.1840 | box_reg: 0.1569 | keypoint: 6.1292 | objectness: 0.0416 | rpn_box_reg: 0.0706 |
# | epoch: 0 | Train loss: 8.2263 | classifier: 0.2050 | box_reg: 0.1609 | keypoint: 7.5435 | objectness: 0.0975 | rpn_box_reg: 0.0249 |
# | epoch: 0 | Train loss: 7.5409 | classifier: 0.1251 | box_reg: 0.1238 | keypoint: 7.0089 | objectness: 0.0729 | rpn_box_reg: 0.0157 |
# | epoch: 0 | Train loss: 5.4144 | classifier: 0.0758 | box_reg: 0.1140 | keypoint: 5.0050 | objectness: 0.0181 | rpn_box_reg: 0.0070 |
# | epoch: 0 | Train loss: 7.7502 | classifier: 0.2059 | box_reg: 0.2198 | keypoint: 6.9565 | objectness: 0.1359 | rpn_box_reg: 0.0376 |
# | epoch: 0 | Train loss: 8.0538 | classifier: 0.1496 | box_reg: 0.1087 | keypoint: 7.4624 | objectness: 0.0784 | rpn_box_reg: 0.0602 |
# | epoch: 1 | Train loss: 4.5694 | classifier: 0.0479 | box_reg: 0.0721 | keypoint: 4.2409 | objectness: 0.0115 | rpn_box_reg: 0.0024 |
# | epoch: 1 | Train loss: 5.2652 | classifier: 0.1107 | box_reg: 0.1502 | keypoint: 4.7961 | objectness: 0.0090 | rpn_box_reg: 0.0045 |
# | epoch: 1 | Train loss: 5.2184 | classifier: 0.0692 | box_reg: 0.0819 | keypoint: 4.8566 | objectness: 0.0122 | rpn_box_reg: 0.0038 |
# | epoch: 1 | Train loss: 6.2054 | classifier: 0.1027 | box_reg: 0.1154 | keypoint: 5.7605 | objectness: 0.0188 | rpn_box_reg: 0.0133 |
# | epoch: 1 | Train loss: 7.1328 | classifier: 0.1172 | box_reg: 0.1489 | keypoint: 6.6405 | objectness: 0.0270 | rpn_box_reg: 0.0044 |
# | epoch: 1 | Train loss: 7.3449 | classifier: 0.1301 | box_reg: 0.1368 | keypoint: 6.8348 | objectness: 0.0376 | rpn_box_reg: 0.0107 |
# | epoch: 1 | Train loss: 5.5620 | classifier: 0.0497 | box_reg: 0.0520 | keypoint: 5.2390 | objectness: 0.0245 | rpn_box_reg: 0.0018 |
# | epoch: 1 | Train loss: 7.6980 | classifier: 0.1391 | box_reg: 0.1248 | keypoint: 7.1457 | objectness: 0.0827 | rpn_box_reg: 0.0108 |
# | epoch: 1 | Train loss: 4.8306 | classifier: 0.0496 | box_reg: 0.0663 | keypoint: 4.4979 | objectness: 0.0178 | rpn_box_reg: 0.0039 |
# | epoch: 1 | Train loss: 6.8792 | classifier: 0.0619 | box_reg: 0.0653 | keypoint: 6.5269 | objectness: 0.0257 | rpn_box_reg: 0.0042 |
# | epoch: 1 | Train loss: 6.8629 | classifier: 0.0681 | box_reg: 0.0694 | keypoint: 6.4644 | objectness: 0.0398 | rpn_box_reg: 0.0260 |
# | epoch: 1 | Train loss: 6.1130 | classifier: 0.0698 | box_reg: 0.1346 | keypoint: 5.6876 | objectness: 0.0197 | rpn_box_reg: 0.0060 |
# | epoch: 1 | Train loss: 5.3458 | classifier: 0.0723 | box_reg: 0.0765 | keypoint: 4.9668 | objectness: 0.0247 | rpn_box_reg: 0.0103 |
# | epoch: 1 | Train loss: 7.9581 | classifier: 0.1273 | box_reg: 0.1278 | keypoint: 7.3540 | objectness: 0.1169 | rpn_box_reg: 0.0368 |
# | epoch: 1 | Train loss: 4.4668 | classifier: 0.0424 | box_reg: 0.0574 | keypoint: 4.1470 | objectness: 0.0224 | rpn_box_reg: 0.0023 |
# | epoch: 1 | Train loss: 5.8340 | classifier: 0.0656 | box_reg: 0.1005 | keypoint: 5.4530 | objectness: 0.0127 | rpn_box_reg: 0.0069 |
# | epoch: 1 | Train loss: 5.2193 | classifier: 0.0511 | box_reg: 0.0745 | keypoint: 4.8871 | objectness: 0.0085 | rpn_box_reg: 0.0027 |
# | epoch: 1 | Train loss: 5.7538 | classifier: 0.1105 | box_reg: 0.1093 | keypoint: 5.2948 | objectness: 0.0133 | rpn_box_reg: 0.0304 |
# | epoch: 1 | Train loss: 6.1450 | classifier: 0.1043 | box_reg: 0.1101 | keypoint: 5.6210 | objectness: 0.1037 | rpn_box_reg: 0.0104 |
# | epoch: 1 | Train loss: 5.4650 | classifier: 0.0955 | box_reg: 0.1250 | keypoint: 5.0029 | objectness: 0.0108 | rpn_box_reg: 0.0354 |
# | epoch: 1 | Train loss: 5.4499 | classifier: 0.0514 | box_reg: 0.0461 | keypoint: 5.1416 | objectness: 0.0130 | rpn_box_reg: 0.0023 |
# | epoch: 1 | Train loss: 7.4061 | classifier: 0.0871 | box_reg: 0.1061 | keypoint: 6.9904 | objectness: 0.0181 | rpn_box_reg: 0.0088 |
# | epoch: 1 | Train loss: 5.0395 | classifier: 0.0567 | box_reg: 0.0850 | keypoint: 4.6942 | objectness: 0.0057 | rpn_box_reg: 0.0021 |
# | epoch: 1 | Train loss: 8.1944 | classifier: 0.1869 | box_reg: 0.1688 | keypoint: 7.5772 | objectness: 0.0522 | rpn_box_reg: 0.0137 |
# | epoch: 1 | Train loss: 6.6820 | classifier: 0.0989 | box_reg: 0.1319 | keypoint: 6.2228 | objectness: 0.0250 | rpn_box_reg: 0.0079 |
# | epoch: 1 | Train loss: 7.1619 | classifier: 0.1862 | box_reg: 0.1863 | keypoint: 6.5349 | objectness: 0.0450 | rpn_box_reg: 0.0137 |
# | epoch: 1 | Train loss: 4.5825 | classifier: 0.0557 | box_reg: 0.0502 | keypoint: 4.2668 | objectness: 0.0108 | rpn_box_reg: 0.0032 |
# | epoch: 1 | Train loss: 5.2762 | classifier: 0.0747 | box_reg: 0.1170 | keypoint: 4.8432 | objectness: 0.0324 | rpn_box_reg: 0.0131 |
# | epoch: 1 | Train loss: 6.0785 | classifier: 0.0464 | box_reg: 0.0674 | keypoint: 5.7548 | objectness: 0.0126 | rpn_box_reg: 0.0015 |
# | epoch: 1 | Train loss: 5.1113 | classifier: 0.0787 | box_reg: 0.1004 | keypoint: 4.7227 | objectness: 0.0109 | rpn_box_reg: 0.0027 |
# | epoch: 1 | Train loss: 6.0440 | classifier: 0.1124 | box_reg: 0.0928 | keypoint: 5.5900 | objectness: 0.0502 | rpn_box_reg: 0.0027 |
# | epoch: 1 | Train loss: 6.6654 | classifier: 0.1111 | box_reg: 0.1217 | keypoint: 6.2010 | objectness: 0.0278 | rpn_box_reg: 0.0079 |
# | epoch: 1 | Train loss: 8.4088 | classifier: 0.2111 | box_reg: 0.2375 | keypoint: 7.7028 | objectness: 0.0579 | rpn_box_reg: 0.0034 |
# | epoch: 1 | Train loss: 6.6627 | classifier: 0.1283 | box_reg: 0.1130 | keypoint: 6.1754 | objectness: 0.0393 | rpn_box_reg: 0.0106 |
# | epoch: 1 | Train loss: 5.3661 | classifier: 0.0540 | box_reg: 0.0872 | keypoint: 5.0120 | objectness: 0.0079 | rpn_box_reg: 0.0088 |
# | epoch: 1 | Train loss: 4.1929 | classifier: 0.0552 | box_reg: 0.0622 | keypoint: 3.8722 | objectness: 0.0027 | rpn_box_reg: 0.0044 |
# | epoch: 1 | Train loss: 5.1403 | classifier: 0.0645 | box_reg: 0.0965 | keypoint: 4.7705 | objectness: 0.0097 | rpn_box_reg: 0.0029 |
# | epoch: 1 | Train loss: 5.0292 | classifier: 0.0679 | box_reg: 0.0832 | keypoint: 4.6671 | objectness: 0.0083 | rpn_box_reg: 0.0063 |
# | epoch: 1 | Train loss: 8.6264 | classifier: 0.1323 | box_reg: 0.0899 | keypoint: 7.8387 | objectness: 0.3068 | rpn_box_reg: 0.0624 |
# | epoch: 1 | Train loss: 6.7633 | classifier: 0.1036 | box_reg: 0.1394 | keypoint: 6.2573 | objectness: 0.0622 | rpn_box_reg: 0.0044 |
# | epoch: 1 | Train loss: 4.5196 | classifier: 0.0619 | box_reg: 0.1184 | keypoint: 4.1309 | objectness: 0.0105 | rpn_box_reg: 0.0015 |
# | epoch: 1 | Train loss: 6.9383 | classifier: 0.0556 | box_reg: 0.0924 | keypoint: 6.5568 | objectness: 0.0186 | rpn_box_reg: 0.0185 |
# | epoch: 1 | Train loss: 7.7850 | classifier: 0.1112 | box_reg: 0.1067 | keypoint: 7.2904 | objectness: 0.0595 | rpn_box_reg: 0.0208 |
# | epoch: 1 | Train loss: 4.4194 | classifier: 0.0369 | box_reg: 0.0348 | keypoint: 4.1255 | objectness: 0.0202 | rpn_box_reg: 0.0055 |
# | epoch: 1 | Train loss: 7.6324 | classifier: 0.0926 | box_reg: 0.0854 | keypoint: 7.1790 | objectness: 0.0673 | rpn_box_reg: 0.0115 |
# | epoch: 1 | Train loss: 6.7336 | classifier: 0.1772 | box_reg: 0.1964 | keypoint: 6.1040 | objectness: 0.0303 | rpn_box_reg: 0.0290 |
# | epoch: 1 | Train loss: 5.1026 | classifier: 0.0638 | box_reg: 0.1043 | keypoint: 4.7145 | objectness: 0.0175 | rpn_box_reg: 0.0057 |
# | epoch: 1 | Train loss: 3.9630 | classifier: 0.0729 | box_reg: 0.0893 | keypoint: 3.5682 | objectness: 0.0145 | rpn_box_reg: 0.0213 |
# | epoch: 1 | Train loss: 6.1849 | classifier: 0.1502 | box_reg: 0.1627 | keypoint: 5.6137 | objectness: 0.0517 | rpn_box_reg: 0.0098 |
# | epoch: 1 | Train loss: 5.2544 | classifier: 0.0878 | box_reg: 0.1265 | keypoint: 4.8045 | objectness: 0.0308 | rpn_box_reg: 0.0080 |
# | epoch: 1 | Train loss: 5.6047 | classifier: 0.0811 | box_reg: 0.0694 | keypoint: 5.2292 | objectness: 0.0187 | rpn_box_reg: 0.0095 |
# | epoch: 1 | Train loss: 6.0253 | classifier: 0.0791 | box_reg: 0.0623 | keypoint: 5.6632 | objectness: 0.0149 | rpn_box_reg: 0.0090 |
# | epoch: 1 | Train loss: 5.0752 | classifier: 0.0797 | box_reg: 0.0876 | keypoint: 4.6923 | objectness: 0.0130 | rpn_box_reg: 0.0057 |
# | epoch: 1 | Train loss: 6.0180 | classifier: 0.0917 | box_reg: 0.0670 | keypoint: 5.5656 | objectness: 0.0480 | rpn_box_reg: 0.0487 |
# | epoch: 1 | Train loss: 7.1646 | classifier: 0.1245 | box_reg: 0.1315 | keypoint: 6.6747 | objectness: 0.0298 | rpn_box_reg: 0.0072 |
# | epoch: 1 | Train loss: 3.9258 | classifier: 0.0433 | box_reg: 0.0508 | keypoint: 3.6267 | objectness: 0.0060 | rpn_box_reg: 0.0020 |
# | epoch: 1 | Train loss: 4.6550 | classifier: 0.0588 | box_reg: 0.0987 | keypoint: 4.2898 | objectness: 0.0081 | rpn_box_reg: 0.0026 |
# | epoch: 1 | Train loss: 4.9448 | classifier: 0.0423 | box_reg: 0.0594 | keypoint: 4.6241 | objectness: 0.0171 | rpn_box_reg: 0.0047 |
# | epoch: 1 | Train loss: 5.1936 | classifier: 0.0741 | box_reg: 0.0993 | keypoint: 4.6844 | objectness: 0.0284 | rpn_box_reg: 0.1102 |
# | epoch: 1 | Train loss: 5.3489 | classifier: 0.0844 | box_reg: 0.1329 | keypoint: 4.9224 | objectness: 0.0071 | rpn_box_reg: 0.0048 |
# | epoch: 1 | Train loss: 6.2966 | classifier: 0.1704 | box_reg: 0.1748 | keypoint: 5.7235 | objectness: 0.0253 | rpn_box_reg: 0.0053 |
# | epoch: 1 | Train loss: 5.7086 | classifier: 0.0550 | box_reg: 0.0749 | keypoint: 5.3704 | objectness: 0.0046 | rpn_box_reg: 0.0063 |
# | epoch: 1 | Train loss: 6.6603 | classifier: 0.0867 | box_reg: 0.1036 | keypoint: 6.2464 | objectness: 0.0151 | rpn_box_reg: 0.0111 |
# | epoch: 1 | Train loss: 7.3182 | classifier: 0.1326 | box_reg: 0.1445 | keypoint: 6.8123 | objectness: 0.0121 | rpn_box_reg: 0.0191 |
# | epoch: 1 | Train loss: 5.2073 | classifier: 0.0674 | box_reg: 0.0816 | keypoint: 4.8395 | objectness: 0.0156 | rpn_box_reg: 0.0056 |
# | epoch: 1 | Train loss: 5.9234 | classifier: 0.1135 | box_reg: 0.1131 | keypoint: 5.4401 | objectness: 0.0503 | rpn_box_reg: 0.0089 |
# | epoch: 1 | Train loss: 7.0130 | classifier: 0.1188 | box_reg: 0.1440 | keypoint: 6.4681 | objectness: 0.0318 | rpn_box_reg: 0.0528 |
# | epoch: 1 | Train loss: 4.8630 | classifier: 0.0386 | box_reg: 0.0514 | keypoint: 4.5686 | objectness: 0.0025 | rpn_box_reg: 0.0043 |
# | epoch: 1 | Train loss: 5.1619 | classifier: 0.0652 | box_reg: 0.0658 | keypoint: 4.8237 | objectness: 0.0066 | rpn_box_reg: 0.0030 |
# | epoch: 1 | Train loss: 6.1006 | classifier: 0.0967 | box_reg: 0.1108 | keypoint: 5.6846 | objectness: 0.0087 | rpn_box_reg: 0.0022 |
# | epoch: 1 | Train loss: 6.9257 | classifier: 0.0991 | box_reg: 0.0922 | keypoint: 6.5211 | objectness: 0.0099 | rpn_box_reg: 0.0057 |
# | epoch: 1 | Train loss: 5.2762 | classifier: 0.1242 | box_reg: 0.1099 | keypoint: 4.7706 | objectness: 0.0439 | rpn_box_reg: 0.0298 |
# | epoch: 1 | Train loss: 8.9036 | classifier: 0.1373 | box_reg: 0.1357 | keypoint: 8.3330 | objectness: 0.0741 | rpn_box_reg: 0.0258 |
# | epoch: 1 | Train loss: 3.4574 | classifier: 0.0497 | box_reg: 0.0688 | keypoint: 3.1349 | objectness: 0.0036 | rpn_box_reg: 0.0025 |
# | epoch: 1 | Train loss: 7.8864 | classifier: 0.2315 | box_reg: 0.2588 | keypoint: 7.1331 | objectness: 0.0430 | rpn_box_reg: 0.0221 |
# | epoch: 1 | Train loss: 6.1794 | classifier: 0.1508 | box_reg: 0.1990 | keypoint: 5.5790 | objectness: 0.0425 | rpn_box_reg: 0.0103 |
# | epoch: 1 | Train loss: 5.3557 | classifier: 0.0803 | box_reg: 0.0961 | keypoint: 4.9404 | objectness: 0.0311 | rpn_box_reg: 0.0096 |
# | epoch: 1 | Train loss: 6.1956 | classifier: 0.0864 | box_reg: 0.0991 | keypoint: 5.7360 | objectness: 0.0720 | rpn_box_reg: 0.0041 |
# | epoch: 1 | Train loss: 5.3378 | classifier: 0.1256 | box_reg: 0.1844 | keypoint: 4.7809 | objectness: 0.0410 | rpn_box_reg: 0.0079 |
# | epoch: 1 | Train loss: 7.6652 | classifier: 0.2226 | box_reg: 0.1696 | keypoint: 6.9606 | objectness: 0.1065 | rpn_box_reg: 0.0077 |
# | epoch: 1 | Train loss: 4.9399 | classifier: 0.0727 | box_reg: 0.1223 | keypoint: 4.5377 | objectness: 0.0082 | rpn_box_reg: 0.0008 |
# | epoch: 1 | Train loss: 6.9768 | classifier: 0.1023 | box_reg: 0.1012 | keypoint: 6.5400 | objectness: 0.0278 | rpn_box_reg: 0.0073 |
# | epoch: 1 | Train loss: 6.2519 | classifier: 0.0917 | box_reg: 0.1346 | keypoint: 5.8066 | objectness: 0.0153 | rpn_box_reg: 0.0054 |
# | epoch: 1 | Train loss: 5.6930 | classifier: 0.1123 | box_reg: 0.1301 | keypoint: 5.2049 | objectness: 0.0401 | rpn_box_reg: 0.0072 |
# | epoch: 1 | Train loss: 4.6515 | classifier: 0.0648 | box_reg: 0.0822 | keypoint: 4.2889 | objectness: 0.0089 | rpn_box_reg: 0.0084 |
# | epoch: 1 | Train loss: 4.8427 | classifier: 0.0948 | box_reg: 0.0994 | keypoint: 4.2974 | objectness: 0.1196 | rpn_box_reg: 0.0331 |
# | epoch: 1 | Train loss: 5.8864 | classifier: 0.0977 | box_reg: 0.1024 | keypoint: 5.4071 | objectness: 0.0719 | rpn_box_reg: 0.0089 |
# | epoch: 1 | Train loss: 6.7856 | classifier: 0.1244 | box_reg: 0.1432 | keypoint: 6.2947 | objectness: 0.0180 | rpn_box_reg: 0.0069 |
# | epoch: 1 | Train loss: 7.4272 | classifier: 0.1204 | box_reg: 0.1510 | keypoint: 6.8950 | objectness: 0.0584 | rpn_box_reg: 0.0040 |
# | epoch: 1 | Train loss: 5.7527 | classifier: 0.0739 | box_reg: 0.1256 | keypoint: 5.3204 | objectness: 0.0259 | rpn_box_reg: 0.0083 |
# | epoch: 1 | Train loss: 5.6490 | classifier: 0.1329 | box_reg: 0.1452 | keypoint: 5.0956 | objectness: 0.0497 | rpn_box_reg: 0.0270 |
# | epoch: 1 | Train loss: 4.2519 | classifier: 0.0596 | box_reg: 0.0880 | keypoint: 3.8893 | objectness: 0.0085 | rpn_box_reg: 0.0078 |
# | epoch: 1 | Train loss: 6.5024 | classifier: 0.1369 | box_reg: 0.1754 | keypoint: 5.9568 | objectness: 0.0190 | rpn_box_reg: 0.0157 |
# | epoch: 1 | Train loss: 6.2957 | classifier: 0.0743 | box_reg: 0.1163 | keypoint: 5.8469 | objectness: 0.0434 | rpn_box_reg: 0.0160 |
# | epoch: 1 | Train loss: 4.2383 | classifier: 0.0651 | box_reg: 0.0532 | keypoint: 3.8931 | objectness: 0.0131 | rpn_box_reg: 0.0150 |
# | epoch: 1 | Train loss: 5.5813 | classifier: 0.0884 | box_reg: 0.1359 | keypoint: 5.1313 | objectness: 0.0161 | rpn_box_reg: 0.0108 |
# | epoch: 1 | Train loss: 5.8937 | classifier: 0.0669 | box_reg: 0.1149 | keypoint: 5.4921 | objectness: 0.0168 | rpn_box_reg: 0.0041 |
# | epoch: 1 | Train loss: 6.4564 | classifier: 0.0941 | box_reg: 0.1196 | keypoint: 6.0031 | objectness: 0.0285 | rpn_box_reg: 0.0122 |
# | epoch: 1 | Train loss: 7.7178 | classifier: 0.1384 | box_reg: 0.1318 | keypoint: 7.1899 | objectness: 0.0489 | rpn_box_reg: 0.0099 |
# | epoch: 1 | Train loss: 4.7531 | classifier: 0.0841 | box_reg: 0.1035 | keypoint: 4.3512 | objectness: 0.0110 | rpn_box_reg: 0.0044 |
# | epoch: 1 | Train loss: 5.8065 | classifier: 0.0920 | box_reg: 0.0828 | keypoint: 5.3995 | objectness: 0.0182 | rpn_box_reg: 0.0150 |
# | epoch: 1 | Train loss: 6.3122 | classifier: 0.1314 | box_reg: 0.1408 | keypoint: 5.7667 | objectness: 0.0692 | rpn_box_reg: 0.0051 |
# | epoch: 1 | Train loss: 6.1414 | classifier: 0.0665 | box_reg: 0.1065 | keypoint: 5.7561 | objectness: 0.0121 | rpn_box_reg: 0.0012 |
# | epoch: 1 | Train loss: 6.1385 | classifier: 0.0922 | box_reg: 0.0864 | keypoint: 5.7269 | objectness: 0.0294 | rpn_box_reg: 0.0046 |
# | epoch: 1 | Train loss: 3.7074 | classifier: 0.0455 | box_reg: 0.0722 | keypoint: 3.3813 | objectness: 0.0084 | rpn_box_reg: 0.0009 |
# | epoch: 1 | Train loss: 5.0151 | classifier: 0.0893 | box_reg: 0.1494 | keypoint: 4.5441 | objectness: 0.0063 | rpn_box_reg: 0.0269 |
# | epoch: 1 | Train loss: 4.7660 | classifier: 0.0602 | box_reg: 0.0912 | keypoint: 4.4076 | objectness: 0.0052 | rpn_box_reg: 0.0025 |
# | epoch: 1 | Train loss: 6.2319 | classifier: 0.0570 | box_reg: 0.0928 | keypoint: 5.8644 | objectness: 0.0163 | rpn_box_reg: 0.0020 |
# | epoch: 1 | Train loss: 4.8800 | classifier: 0.0925 | box_reg: 0.1166 | keypoint: 4.4540 | objectness: 0.0107 | rpn_box_reg: 0.0068 |
# | epoch: 1 | Train loss: 5.5939 | classifier: 0.0724 | box_reg: 0.0847 | keypoint: 5.2037 | objectness: 0.0206 | rpn_box_reg: 0.0132 |
# | epoch: 1 | Train loss: 4.2502 | classifier: 0.0306 | box_reg: 0.0306 | keypoint: 3.9783 | objectness: 0.0062 | rpn_box_reg: 0.0050 |
# | epoch: 1 | Train loss: 5.7406 | classifier: 0.0516 | box_reg: 0.0818 | keypoint: 5.3676 | objectness: 0.0303 | rpn_box_reg: 0.0097 |
# | epoch: 1 | Train loss: 4.0097 | classifier: 0.0346 | box_reg: 0.0360 | keypoint: 3.7354 | objectness: 0.0031 | rpn_box_reg: 0.0010 |
# | epoch: 1 | Train loss: 5.4862 | classifier: 0.1471 | box_reg: 0.1567 | keypoint: 4.9537 | objectness: 0.0271 | rpn_box_reg: 0.0021 |
# | epoch: 1 | Train loss: 6.8159 | classifier: 0.0908 | box_reg: 0.1177 | keypoint: 6.3913 | objectness: 0.0104 | rpn_box_reg: 0.0060 |
# | epoch: 1 | Train loss: 5.1186 | classifier: 0.0564 | box_reg: 0.1174 | keypoint: 4.7366 | objectness: 0.0055 | rpn_box_reg: 0.0030 |
# | epoch: 1 | Train loss: 4.5135 | classifier: 0.0506 | box_reg: 0.0567 | keypoint: 4.1892 | objectness: 0.0118 | rpn_box_reg: 0.0054 |
# | epoch: 1 | Train loss: 5.3343 | classifier: 0.0549 | box_reg: 0.0731 | keypoint: 4.9900 | objectness: 0.0140 | rpn_box_reg: 0.0026 |
# | epoch: 1 | Train loss: 5.3597 | classifier: 0.0948 | box_reg: 0.0912 | keypoint: 4.9207 | objectness: 0.0429 | rpn_box_reg: 0.0103 |
# | epoch: 1 | Train loss: 7.5016 | classifier: 0.0766 | box_reg: 0.0791 | keypoint: 7.1292 | objectness: 0.0126 | rpn_box_reg: 0.0042 |
# | epoch: 1 | Train loss: 7.8258 | classifier: 0.1003 | box_reg: 0.1297 | keypoint: 7.3591 | objectness: 0.0218 | rpn_box_reg: 0.0150 |
# | epoch: 1 | Train loss: 3.7426 | classifier: 0.0416 | box_reg: 0.0714 | keypoint: 3.4139 | objectness: 0.0083 | rpn_box_reg: 0.0074 |
# | epoch: 1 | Train loss: 5.1390 | classifier: 0.0551 | box_reg: 0.1080 | keypoint: 4.7548 | objectness: 0.0157 | rpn_box_reg: 0.0053 |
# | epoch: 1 | Valid loss: 3.8442 | classifier: 0.0358 | box_reg: 0.0457 | keypoint: 3.7427 | objectness: 0.0137 | rpn_box_reg: 0.0062 |
# | epoch: 1 | Valid loss: 6.5097 | classifier: 0.0927 | box_reg: 0.0962 | keypoint: 6.2692 | objectness: 0.0224 | rpn_box_reg: 0.0292 |
# | epoch: 1 | Valid loss: 5.3674 | classifier: 0.0464 | box_reg: 0.0726 | keypoint: 5.1721 | objectness: 0.0589 | rpn_box_reg: 0.0175 |
# | epoch: 1 | Valid loss: 6.4638 | classifier: 0.0913 | box_reg: 0.0710 | keypoint: 6.2400 | objectness: 0.0477 | rpn_box_reg: 0.0139 |
# | epoch: 1 | Valid loss: 5.8413 | classifier: 0.0888 | box_reg: 0.0673 | keypoint: 5.6413 | objectness: 0.0341 | rpn_box_reg: 0.0099 |
# | epoch: 1 | Valid loss: 4.9732 | classifier: 0.0386 | box_reg: 0.0246 | keypoint: 4.8275 | objectness: 0.0691 | rpn_box_reg: 0.0134 |
# | epoch: 1 | Valid loss: 6.4141 | classifier: 0.0668 | box_reg: 0.0632 | keypoint: 6.2259 | objectness: 0.0541 | rpn_box_reg: 0.0041 |
# | epoch: 1 | Valid loss: 4.6678 | classifier: 0.0337 | box_reg: 0.0257 | keypoint: 4.5766 | objectness: 0.0203 | rpn_box_reg: 0.0116 |
# | epoch: 1 | Valid loss: 6.7496 | classifier: 0.1449 | box_reg: 0.1169 | keypoint: 6.4136 | objectness: 0.0644 | rpn_box_reg: 0.0097 |
# | epoch: 1 | Valid loss: 5.4359 | classifier: 0.0568 | box_reg: 0.0611 | keypoint: 5.3055 | objectness: 0.0086 | rpn_box_reg: 0.0039 |
# | epoch: 1 | Valid loss: 5.8366 | classifier: 0.0654 | box_reg: 0.0460 | keypoint: 5.6582 | objectness: 0.0563 | rpn_box_reg: 0.0108 |
# | epoch: 1 | Valid loss: 7.8501 | classifier: 0.2130 | box_reg: 0.2314 | keypoint: 7.3183 | objectness: 0.0495 | rpn_box_reg: 0.0378 |
# | epoch: 1 | Valid loss: 4.6825 | classifier: 0.0575 | box_reg: 0.0668 | keypoint: 4.4506 | objectness: 0.0847 | rpn_box_reg: 0.0228 |
# | epoch: 1 | Valid loss: 7.6136 | classifier: 0.1670 | box_reg: 0.1509 | keypoint: 7.0787 | objectness: 0.1991 | rpn_box_reg: 0.0179 |
# | epoch: 1 | Valid loss: 6.5626 | classifier: 0.1361 | box_reg: 0.1492 | keypoint: 6.2330 | objectness: 0.0166 | rpn_box_reg: 0.0277 |
# | epoch: 1 | Valid loss: 6.8196 | classifier: 0.0719 | box_reg: 0.0489 | keypoint: 6.6549 | objectness: 0.0394 | rpn_box_reg: 0.0044 |
# | epoch: 1 | Valid loss: 4.2746 | classifier: 0.0526 | box_reg: 0.0272 | keypoint: 4.1376 | objectness: 0.0481 | rpn_box_reg: 0.0091 |
# | epoch: 1 | Valid loss: 6.1377 | classifier: 0.1070 | box_reg: 0.1291 | keypoint: 5.8495 | objectness: 0.0463 | rpn_box_reg: 0.0059 |
# | epoch: 1 | Valid loss: 6.6368 | classifier: 0.1212 | box_reg: 0.1387 | keypoint: 6.3473 | objectness: 0.0173 | rpn_box_reg: 0.0124 |
# | epoch: 1 | Valid loss: 5.8727 | classifier: 0.0662 | box_reg: 0.0564 | keypoint: 5.6710 | objectness: 0.0717 | rpn_box_reg: 0.0073 |
# | epoch: 1 | Valid loss: 6.1957 | classifier: 0.0665 | box_reg: 0.0306 | keypoint: 6.0817 | objectness: 0.0117 | rpn_box_reg: 0.0052 |
# | epoch: 1 | Valid loss: 5.8239 | classifier: 0.0594 | box_reg: 0.0649 | keypoint: 5.6819 | objectness: 0.0127 | rpn_box_reg: 0.0050 |
# | epoch: 1 | Valid loss: 4.5505 | classifier: 0.0669 | box_reg: 0.0567 | keypoint: 4.3985 | objectness: 0.0229 | rpn_box_reg: 0.0056 |
# | epoch: 1 | Valid loss: 8.0986 | classifier: 0.1603 | box_reg: 0.1812 | keypoint: 7.6783 | objectness: 0.0576 | rpn_box_reg: 0.0213 |
# | epoch: 1 | Valid loss: 7.4480 | classifier: 0.1622 | box_reg: 0.2239 | keypoint: 6.9604 | objectness: 0.0672 | rpn_box_reg: 0.0343 |
# | epoch: 1 | Valid loss: 7.9826 | classifier: 0.1485 | box_reg: 0.1707 | keypoint: 7.6180 | objectness: 0.0386 | rpn_box_reg: 0.0068 |
# | epoch: 1 | Valid loss: 4.8615 | classifier: 0.0797 | box_reg: 0.0498 | keypoint: 4.6922 | objectness: 0.0320 | rpn_box_reg: 0.0078 |
# | epoch: 1 | Valid loss: 5.2757 | classifier: 0.0699 | box_reg: 0.0476 | keypoint: 5.1426 | objectness: 0.0079 | rpn_box_reg: 0.0077 |
# | epoch: 1 | Valid loss: 6.0541 | classifier: 0.0739 | box_reg: 0.0658 | keypoint: 5.8756 | objectness: 0.0300 | rpn_box_reg: 0.0088 |
# | epoch: 1 | Valid loss: 9.0512 | classifier: 0.0432 | box_reg: 0.0198 | keypoint: 4.7681 | objectness: 3.3511 | rpn_box_reg: 0.8689 |
#  > VALIDATION SET LOSS MEAN :  5.7424
# | epoch: 2 | Train loss: 4.1488 | classifier: 0.0499 | box_reg: 0.0668 | keypoint: 3.8235 | objectness: 0.0058 | rpn_box_reg: 0.0028 |
# | epoch: 2 | Train loss: 6.2592 | classifier: 0.0670 | box_reg: 0.0599 | keypoint: 5.9061 | objectness: 0.0245 | rpn_box_reg: 0.0017 |
# | epoch: 2 | Train loss: 5.7520 | classifier: 0.1087 | box_reg: 0.1075 | keypoint: 5.3164 | objectness: 0.0161 | rpn_box_reg: 0.0031 |
# | epoch: 2 | Train loss: 3.1676 | classifier: 0.0394 | box_reg: 0.0657 | keypoint: 2.8424 | objectness: 0.0110 | rpn_box_reg: 0.0091 |
# | epoch: 2 | Train loss: 3.9727 | classifier: 0.0452 | box_reg: 0.0484 | keypoint: 3.3780 | objectness: 0.1425 | rpn_box_reg: 0.1583 |
# | epoch: 2 | Train loss: 4.7451 | classifier: 0.0586 | box_reg: 0.0792 | keypoint: 4.3692 | objectness: 0.0299 | rpn_box_reg: 0.0079 |
# | epoch: 2 | Train loss: 4.6189 | classifier: 0.0472 | box_reg: 0.0513 | keypoint: 4.2946 | objectness: 0.0166 | rpn_box_reg: 0.0089 |
# | epoch: 2 | Train loss: 7.6470 | classifier: 0.1162 | box_reg: 0.1424 | keypoint: 7.1650 | objectness: 0.0143 | rpn_box_reg: 0.0087 |
# | epoch: 2 | Train loss: 4.2702 | classifier: 0.0459 | box_reg: 0.0579 | keypoint: 3.9536 | objectness: 0.0112 | rpn_box_reg: 0.0013 |
# | epoch: 2 | Train loss: 6.1213 | classifier: 0.0461 | box_reg: 0.0759 | keypoint: 5.7896 | objectness: 0.0073 | rpn_box_reg: 0.0020 |
# | epoch: 2 | Train loss: 8.9113 | classifier: 0.2342 | box_reg: 0.2263 | keypoint: 8.2048 | objectness: 0.0212 | rpn_box_reg: 0.0244 |
# | epoch: 2 | Train loss: 7.7951 | classifier: 0.0978 | box_reg: 0.1113 | keypoint: 7.3531 | objectness: 0.0249 | rpn_box_reg: 0.0075 |
# | epoch: 2 | Train loss: 5.6027 | classifier: 0.1105 | box_reg: 0.1126 | keypoint: 5.1220 | objectness: 0.0427 | rpn_box_reg: 0.0142 |
# | epoch: 2 | Train loss: 7.4462 | classifier: 0.1405 | box_reg: 0.1507 | keypoint: 6.8954 | objectness: 0.0549 | rpn_box_reg: 0.0040 |
# | epoch: 2 | Train loss: 7.0582 | classifier: 0.1620 | box_reg: 0.2225 | keypoint: 6.4287 | objectness: 0.0271 | rpn_box_reg: 0.0173 |
# | epoch: 2 | Train loss: 5.6599 | classifier: 0.0756 | box_reg: 0.0952 | keypoint: 5.2547 | objectness: 0.0225 | rpn_box_reg: 0.0112 |
# | epoch: 2 | Train loss: 6.8636 | classifier: 0.0767 | box_reg: 0.0871 | keypoint: 6.4236 | objectness: 0.0666 | rpn_box_reg: 0.0088 |
# | epoch: 2 | Train loss: 3.4520 | classifier: 0.0405 | box_reg: 0.0461 | keypoint: 3.1565 | objectness: 0.0057 | rpn_box_reg: 0.0024 |
# | epoch: 2 | Train loss: 4.9464 | classifier: 0.0375 | box_reg: 0.0790 | keypoint: 4.6233 | objectness: 0.0040 | rpn_box_reg: 0.0018 |
# | epoch: 2 | Train loss: 4.0914 | classifier: 0.0648 | box_reg: 0.1081 | keypoint: 3.6671 | objectness: 0.0434 | rpn_box_reg: 0.0071 |
# | epoch: 2 | Train loss: 5.3884 | classifier: 0.0339 | box_reg: 0.0610 | keypoint: 5.0625 | objectness: 0.0260 | rpn_box_reg: 0.0042 |
# | epoch: 2 | Train loss: 4.7345 | classifier: 0.0818 | box_reg: 0.1121 | keypoint: 4.3093 | objectness: 0.0244 | rpn_box_reg: 0.0060 |
# | epoch: 2 | Train loss: 4.3023 | classifier: 0.0494 | box_reg: 0.0568 | keypoint: 3.9761 | objectness: 0.0164 | rpn_box_reg: 0.0026 |
# | epoch: 2 | Train loss: 5.0018 | classifier: 0.0677 | box_reg: 0.0860 | keypoint: 4.6219 | objectness: 0.0135 | rpn_box_reg: 0.0117 |
# | epoch: 2 | Train loss: 6.2301 | classifier: 0.0693 | box_reg: 0.0917 | keypoint: 5.8481 | objectness: 0.0150 | rpn_box_reg: 0.0049 |
# | epoch: 2 | Train loss: 4.8497 | classifier: 0.0813 | box_reg: 0.1031 | keypoint: 4.4430 | objectness: 0.0105 | rpn_box_reg: 0.0107 |
# | epoch: 2 | Train loss: 3.6077 | classifier: 0.0527 | box_reg: 0.0602 | keypoint: 3.2799 | objectness: 0.0041 | rpn_box_reg: 0.0097 |
# | epoch: 2 | Train loss: 5.6365 | classifier: 0.0950 | box_reg: 0.1035 | keypoint: 5.2188 | objectness: 0.0078 | rpn_box_reg: 0.0102 |
# | epoch: 2 | Train loss: 6.6915 | classifier: 0.0970 | box_reg: 0.0980 | keypoint: 6.2386 | objectness: 0.0447 | rpn_box_reg: 0.0119 |
# | epoch: 2 | Train loss: 5.9372 | classifier: 0.1187 | box_reg: 0.1746 | keypoint: 5.4161 | objectness: 0.0123 | rpn_box_reg: 0.0141 |
# | epoch: 2 | Train loss: 5.8600 | classifier: 0.1041 | box_reg: 0.1581 | keypoint: 5.3647 | objectness: 0.0156 | rpn_box_reg: 0.0161 |
# | epoch: 2 | Train loss: 5.0334 | classifier: 0.1121 | box_reg: 0.1428 | keypoint: 4.5525 | objectness: 0.0191 | rpn_box_reg: 0.0056 |
# | epoch: 2 | Train loss: 5.6362 | classifier: 0.0834 | box_reg: 0.1159 | keypoint: 5.1865 | objectness: 0.0379 | rpn_box_reg: 0.0111 |
# | epoch: 2 | Train loss: 6.4814 | classifier: 0.0827 | box_reg: 0.1272 | keypoint: 6.0125 | objectness: 0.0504 | rpn_box_reg: 0.0072 |
# | epoch: 2 | Train loss: 5.1604 | classifier: 0.0899 | box_reg: 0.1214 | keypoint: 4.6331 | objectness: 0.0348 | rpn_box_reg: 0.0797 |
# | epoch: 2 | Train loss: 5.8170 | classifier: 0.0809 | box_reg: 0.1005 | keypoint: 5.3823 | objectness: 0.0175 | rpn_box_reg: 0.0344 |
# | epoch: 2 | Train loss: 7.1323 | classifier: 0.0971 | box_reg: 0.0938 | keypoint: 6.6776 | objectness: 0.0311 | rpn_box_reg: 0.0311 |
# | epoch: 2 | Train loss: 4.3582 | classifier: 0.0740 | box_reg: 0.1159 | keypoint: 3.9202 | objectness: 0.0245 | rpn_box_reg: 0.0220 |
# | epoch: 2 | Train loss: 3.5274 | classifier: 0.0325 | box_reg: 0.0452 | keypoint: 3.2407 | objectness: 0.0027 | rpn_box_reg: 0.0046 |
# | epoch: 2 | Train loss: 7.5016 | classifier: 0.1703 | box_reg: 0.1680 | keypoint: 6.9071 | objectness: 0.0413 | rpn_box_reg: 0.0131 |
# | epoch: 2 | Train loss: 4.7788 | classifier: 0.0487 | box_reg: 0.0670 | keypoint: 4.4505 | objectness: 0.0084 | rpn_box_reg: 0.0026 |
# | epoch: 2 | Train loss: 5.7666 | classifier: 0.0622 | box_reg: 0.1067 | keypoint: 5.3666 | objectness: 0.0191 | rpn_box_reg: 0.0104 |
# | epoch: 2 | Train loss: 4.2817 | classifier: 0.0571 | box_reg: 0.0805 | keypoint: 3.9263 | objectness: 0.0141 | rpn_box_reg: 0.0020 |
# | epoch: 2 | Train loss: 7.7391 | classifier: 0.1372 | box_reg: 0.1370 | keypoint: 7.1651 | objectness: 0.0663 | rpn_box_reg: 0.0317 |
# | epoch: 2 | Train loss: 5.0356 | classifier: 0.0544 | box_reg: 0.0879 | keypoint: 4.6802 | objectness: 0.0073 | rpn_box_reg: 0.0041 |
# | epoch: 2 | Train loss: 5.4518 | classifier: 0.0889 | box_reg: 0.0997 | keypoint: 5.0318 | objectness: 0.0156 | rpn_box_reg: 0.0139 |
# | epoch: 2 | Train loss: 4.1869 | classifier: 0.0359 | box_reg: 0.0683 | keypoint: 3.8741 | objectness: 0.0048 | rpn_box_reg: 0.0020 |
# | epoch: 2 | Train loss: 3.3017 | classifier: 0.0294 | box_reg: 0.0449 | keypoint: 3.0107 | objectness: 0.0141 | rpn_box_reg: 0.0007 |
# | epoch: 2 | Train loss: 5.0615 | classifier: 0.0961 | box_reg: 0.1166 | keypoint: 4.6212 | objectness: 0.0179 | rpn_box_reg: 0.0077 |
# | epoch: 2 | Train loss: 4.6925 | classifier: 0.1242 | box_reg: 0.1385 | keypoint: 4.1639 | objectness: 0.0548 | rpn_box_reg: 0.0091 |
# | epoch: 2 | Train loss: 3.9860 | classifier: 0.0420 | box_reg: 0.0547 | keypoint: 3.6686 | objectness: 0.0121 | rpn_box_reg: 0.0065 |
# | epoch: 2 | Train loss: 4.7565 | classifier: 0.0747 | box_reg: 0.1242 | keypoint: 4.3205 | objectness: 0.0284 | rpn_box_reg: 0.0066 |
# | epoch: 2 | Train loss: 7.8217 | classifier: 0.0906 | box_reg: 0.0908 | keypoint: 7.3400 | objectness: 0.0849 | rpn_box_reg: 0.0133 |
# | epoch: 2 | Train loss: 5.7025 | classifier: 0.0704 | box_reg: 0.0936 | keypoint: 5.3268 | objectness: 0.0041 | rpn_box_reg: 0.0055 |
# | epoch: 2 | Train loss: 4.2383 | classifier: 0.0704 | box_reg: 0.1203 | keypoint: 3.8375 | objectness: 0.0050 | rpn_box_reg: 0.0030 |
# | epoch: 2 | Train loss: 7.5794 | classifier: 0.1691 | box_reg: 0.1952 | keypoint: 6.9552 | objectness: 0.0387 | rpn_box_reg: 0.0189 |
# | epoch: 2 | Train loss: 4.5319 | classifier: 0.0628 | box_reg: 0.0709 | keypoint: 3.9886 | objectness: 0.0551 | rpn_box_reg: 0.1522 |
# | epoch: 2 | Train loss: 4.9103 | classifier: 0.0647 | box_reg: 0.0555 | keypoint: 4.5472 | objectness: 0.0230 | rpn_box_reg: 0.0176 |
# | epoch: 2 | Train loss: 5.9268 | classifier: 0.0544 | box_reg: 0.1070 | keypoint: 5.5380 | objectness: 0.0219 | rpn_box_reg: 0.0032 |
# | epoch: 2 | Train loss: 7.0466 | classifier: 0.1476 | box_reg: 0.1939 | keypoint: 6.4722 | objectness: 0.0210 | rpn_box_reg: 0.0095 |
# | epoch: 2 | Train loss: 7.1595 | classifier: 0.1511 | box_reg: 0.1821 | keypoint: 6.5541 | objectness: 0.0657 | rpn_box_reg: 0.0040 |
# | epoch: 2 | Train loss: 4.6610 | classifier: 0.0339 | box_reg: 0.0553 | keypoint: 4.3586 | objectness: 0.0080 | rpn_box_reg: 0.0028 |
# | epoch: 2 | Train loss: 5.4770 | classifier: 0.0536 | box_reg: 0.0725 | keypoint: 5.1332 | objectness: 0.0132 | rpn_box_reg: 0.0021 |
# | epoch: 2 | Train loss: 4.7779 | classifier: 0.0609 | box_reg: 0.0577 | keypoint: 4.4233 | objectness: 0.0178 | rpn_box_reg: 0.0157 |
# | epoch: 2 | Train loss: 5.1661 | classifier: 0.0603 | box_reg: 0.0581 | keypoint: 4.8281 | objectness: 0.0132 | rpn_box_reg: 0.0038 |
# | epoch: 2 | Train loss: 6.8927 | classifier: 0.1247 | box_reg: 0.1600 | keypoint: 6.3445 | objectness: 0.0549 | rpn_box_reg: 0.0060 |
# | epoch: 2 | Train loss: 4.2366 | classifier: 0.0579 | box_reg: 0.0917 | keypoint: 3.8645 | objectness: 0.0098 | rpn_box_reg: 0.0100 |
# | epoch: 2 | Train loss: 4.2556 | classifier: 0.0360 | box_reg: 0.0516 | keypoint: 3.9550 | objectness: 0.0087 | rpn_box_reg: 0.0016 |
# | epoch: 2 | Train loss: 5.2286 | classifier: 0.1191 | box_reg: 0.1278 | keypoint: 4.7625 | objectness: 0.0096 | rpn_box_reg: 0.0068 |
# | epoch: 2 | Train loss: 5.3171 | classifier: 0.0398 | box_reg: 0.0774 | keypoint: 4.9863 | objectness: 0.0087 | rpn_box_reg: 0.0022 |
# | epoch: 2 | Train loss: 6.3063 | classifier: 0.0612 | box_reg: 0.1218 | keypoint: 5.9037 | objectness: 0.0140 | rpn_box_reg: 0.0027 |
# | epoch: 2 | Train loss: 3.2398 | classifier: 0.0295 | box_reg: 0.0295 | keypoint: 2.9748 | objectness: 0.0014 | rpn_box_reg: 0.0017 |
# | epoch: 2 | Train loss: 6.2162 | classifier: 0.1353 | box_reg: 0.1405 | keypoint: 5.6722 | objectness: 0.0505 | rpn_box_reg: 0.0147 |
# | epoch: 2 | Train loss: 4.7998 | classifier: 0.0602 | box_reg: 0.0709 | keypoint: 4.4524 | objectness: 0.0117 | rpn_box_reg: 0.0015 |
# | epoch: 2 | Train loss: 5.2126 | classifier: 0.0615 | box_reg: 0.0595 | keypoint: 4.8807 | objectness: 0.0064 | rpn_box_reg: 0.0014 |
# ...
# | epoch: 7 | Train loss: 3.0581 | classifier: 0.0305 | box_reg: 0.0240 | keypoint: 2.7773 | objectness: 0.0008 | rpn_box_reg: 0.0022 |
# | epoch: 7 | Train loss: 3.1080 | classifier: 0.0349 | box_reg: 0.0398 | keypoint: 2.8059 | objectness: 0.0012 | rpn_box_reg: 0.0030 |
# | epoch: 7 | Train loss: 3.7334 | classifier: 0.0273 | box_reg: 0.0428 | keypoint: 3.4323 | objectness: 0.0059 | rpn_box_reg: 0.0018 |
# | epoch: 7 | Train loss: 7.3402 | classifier: 0.1414 | box_reg: 0.1515 | keypoint: 6.7805 | objectness: 0.0125 | rpn_box_reg: 0.0311 |
# | epoch: 7 | Train loss: 3.6225 | classifier: 0.0554 | box_reg: 0.0696 | keypoint: 3.2420 | objectness: 0.0296 | rpn_box_reg: 0.0026 |
# | epoch: 7 | Train loss: 5.8731 | classifier: 0.0743 | box_reg: 0.0745 | keypoint: 5.4717 | objectness: 0.0270 | rpn_box_reg: 0.0023 |
# | epoch: 7 | Train loss: 5.9675 | classifier: 0.0660 | box_reg: 0.0987 | keypoint: 5.5714 | objectness: 0.0028 | rpn_box_reg: 0.0052 |
# | epoch: 7 | Valid loss: 5.7146 | classifier: 0.0520 | box_reg: 0.0567 | keypoint: 5.5838 | objectness: 0.0186 | rpn_box_reg: 0.0035 |
# | epoch: 7 | Valid loss: 3.8323 | classifier: 0.0277 | box_reg: 0.0324 | keypoint: 3.7474 | objectness: 0.0215 | rpn_box_reg: 0.0033 |
# | epoch: 7 | Valid loss: 4.7677 | classifier: 0.0785 | box_reg: 0.0642 | keypoint: 4.5374 | objectness: 0.0651 | rpn_box_reg: 0.0224 |
# | epoch: 7 | Valid loss: 4.1537 | classifier: 0.0665 | box_reg: 0.0374 | keypoint: 4.0411 | objectness: 0.0030 | rpn_box_reg: 0.0057 |
# | epoch: 7 | Valid loss: 4.0907 | classifier: 0.0329 | box_reg: 0.0431 | keypoint: 4.0033 | objectness: 0.0071 | rpn_box_reg: 0.0043 |
# | epoch: 7 | Valid loss: 4.0852 | classifier: 0.0306 | box_reg: 0.0612 | keypoint: 3.9850 | objectness: 0.0063 | rpn_box_reg: 0.0022 |
# | epoch: 7 | Valid loss: 6.3706 | classifier: 0.0902 | box_reg: 0.0948 | keypoint: 6.1401 | objectness: 0.0421 | rpn_box_reg: 0.0033 |
# | epoch: 7 | Valid loss: 6.3997 | classifier: 0.0789 | box_reg: 0.0826 | keypoint: 6.1736 | objectness: 0.0479 | rpn_box_reg: 0.0166 |
# | epoch: 7 | Valid loss: 2.9412 | classifier: 0.0423 | box_reg: 0.0268 | keypoint: 2.8594 | objectness: 0.0056 | rpn_box_reg: 0.0070 |
# | epoch: 7 | Valid loss: 6.3763 | classifier: 0.0930 | box_reg: 0.1204 | keypoint: 6.1319 | objectness: 0.0264 | rpn_box_reg: 0.0046 |
# | epoch: 7 | Valid loss: 5.3014 | classifier: 0.0716 | box_reg: 0.0836 | keypoint: 5.1300 | objectness: 0.0102 | rpn_box_reg: 0.0060 |
# | epoch: 7 | Valid loss: 6.6792 | classifier: 0.1032 | box_reg: 0.1205 | keypoint: 6.3967 | objectness: 0.0462 | rpn_box_reg: 0.0127 |
# | epoch: 7 | Valid loss: 2.4117 | classifier: 0.0456 | box_reg: 0.0279 | keypoint: 2.2907 | objectness: 0.0433 | rpn_box_reg: 0.0042 |
# | epoch: 7 | Valid loss: 3.2100 | classifier: 0.0634 | box_reg: 0.0674 | keypoint: 3.0653 | objectness: 0.0110 | rpn_box_reg: 0.0030 |
# | epoch: 7 | Valid loss: 6.5244 | classifier: 0.0964 | box_reg: 0.0857 | keypoint: 6.3143 | objectness: 0.0261 | rpn_box_reg: 0.0020 |
# | epoch: 7 | Valid loss: 6.5047 | classifier: 0.0752 | box_reg: 0.0968 | keypoint: 6.3158 | objectness: 0.0150 | rpn_box_reg: 0.0018 |
# | epoch: 7 | Valid loss: 5.2695 | classifier: 0.1163 | box_reg: 0.1255 | keypoint: 5.0027 | objectness: 0.0224 | rpn_box_reg: 0.0026 |
# | epoch: 7 | Valid loss: 4.3971 | classifier: 0.0314 | box_reg: 0.0416 | keypoint: 4.3136 | objectness: 0.0082 | rpn_box_reg: 0.0022 |
# | epoch: 7 | Valid loss: 2.9050 | classifier: 0.0232 | box_reg: 0.0291 | keypoint: 2.8478 | objectness: 0.0026 | rpn_box_reg: 0.0023 |
# | epoch: 7 | Valid loss: 8.1626 | classifier: 0.1468 | box_reg: 0.1493 | keypoint: 7.8069 | objectness: 0.0562 | rpn_box_reg: 0.0035 |
# | epoch: 7 | Valid loss: 7.4660 | classifier: 0.1260 | box_reg: 0.1050 | keypoint: 7.2071 | objectness: 0.0234 | rpn_box_reg: 0.0046 |
# | epoch: 7 | Valid loss: 3.8179 | classifier: 0.0376 | box_reg: 0.0434 | keypoint: 3.7313 | objectness: 0.0033 | rpn_box_reg: 0.0024 |
# | epoch: 7 | Valid loss: 2.8659 | classifier: 0.0420 | box_reg: 0.0190 | keypoint: 2.7327 | objectness: 0.0636 | rpn_box_reg: 0.0086 |
# | epoch: 7 | Valid loss: 8.2956 | classifier: 0.0710 | box_reg: 0.0594 | keypoint: 7.9070 | objectness: 0.2180 | rpn_box_reg: 0.0402 |
# | epoch: 7 | Valid loss: 3.3783 | classifier: 0.0322 | box_reg: 0.0291 | keypoint: 3.2779 | objectness: 0.0065 | rpn_box_reg: 0.0327 |
# | epoch: 7 | Valid loss: 4.4714 | classifier: 0.0379 | box_reg: 0.0411 | keypoint: 4.3650 | objectness: 0.0231 | rpn_box_reg: 0.0044 |
# | epoch: 7 | Valid loss: 4.8710 | classifier: 0.1166 | box_reg: 0.0965 | keypoint: 4.6360 | objectness: 0.0161 | rpn_box_reg: 0.0057 |
# | epoch: 7 | Valid loss: 3.1277 | classifier: 0.0281 | box_reg: 0.0320 | keypoint: 3.0606 | objectness: 0.0031 | rpn_box_reg: 0.0039 |
# | epoch: 7 | Valid loss: 4.0879 | classifier: 0.0341 | box_reg: 0.0403 | keypoint: 3.9962 | objectness: 0.0148 | rpn_box_reg: 0.0026 |
# | epoch: 7 | Valid loss: 3.2108 | classifier: 0.0458 | box_reg: 0.0342 | keypoint: 3.1048 | objectness: 0.0208 | rpn_box_reg: 0.0052 |
#  > VALIDATION SET LOSS MEAN :  4.9873
# | epoch: 8 | Train loss: 2.4325 | classifier: 0.0155 | box_reg: 0.0229 | keypoint: 2.1663 | objectness: 0.0024 | rpn_box_reg: 0.0022 |
# | epoch: 8 | Train loss: 5.7217 | classifier: 0.0521 | box_reg: 0.0424 | keypoint: 5.3621 | objectness: 0.0274 | rpn_box_reg: 0.0144 |
# | epoch: 8 | Train loss: 2.6274 | classifier: 0.0220 | box_reg: 0.0383 | keypoint: 2.3395 | objectness: 0.0011 | rpn_box_reg: 0.0032 |
# | epoch: 8 | Train loss: 5.3158 | classifier: 0.0668 | box_reg: 0.0809 | keypoint: 4.9234 | objectness: 0.0188 | rpn_box_reg: 0.0026 |
# | epoch: 8 | Train loss: 6.3938 | classifier: 0.1429 | box_reg: 0.1380 | keypoint: 5.8491 | objectness: 0.0316 | rpn_box_reg: 0.0090 |
# | epoch: 8 | Train loss: 5.9240 | classifier: 0.0711 | box_reg: 0.0934 | keypoint: 5.4715 | objectness: 0.0611 | rpn_box_reg: 0.0036 |
# | epoch: 8 | Train loss: 5.0887 | classifier: 0.1047 | box_reg: 0.1343 | keypoint: 4.6061 | objectness: 0.0185 | rpn_box_reg: 0.0018 |
# | epoch: 8 | Train loss: 3.8451 | classifier: 0.0242 | box_reg: 0.0369 | keypoint: 3.5561 | objectness: 0.0043 | rpn_box_reg: 0.0004 |
# | epoch: 8 | Train loss: 4.5786 | classifier: 0.0490 | box_reg: 0.0575 | keypoint: 4.2169 | objectness: 0.0268 | rpn_box_reg: 0.0051 |
# | epoch: 8 | Train loss: 4.3491 | classifier: 0.0416 | box_reg: 0.0486 | keypoint: 4.0281 | objectness: 0.0056 | rpn_box_reg: 0.0018 |
# | epoch: 8 | Train loss: 4.0566 | classifier: 0.0184 | box_reg: 0.0552 | keypoint: 3.7585 | objectness: 0.0006 | rpn_box_reg: 0.0006 |
# | epoch: 8 | Train loss: 5.7962 | classifier: 0.0551 | box_reg: 0.0680 | keypoint: 5.3918 | objectness: 0.0431 | rpn_box_reg: 0.0149 |
# | epoch: 8 | Train loss: 5.5268 | classifier: 0.0756 | box_reg: 0.0918 | keypoint: 5.1067 | objectness: 0.0197 | rpn_box_reg: 0.0098 |
# | epoch: 8 | Train loss: 5.8027 | classifier: 0.0990 | box_reg: 0.0882 | keypoint: 5.3486 | objectness: 0.0226 | rpn_box_reg: 0.0210 |
# | epoch: 8 | Train loss: 3.0057 | classifier: 0.0322 | box_reg: 0.0439 | keypoint: 2.6973 | objectness: 0.0054 | rpn_box_reg: 0.0036 |
# | epoch: 8 | Train loss: 4.6437 | classifier: 0.0567 | box_reg: 0.0725 | keypoint: 4.2791 | objectness: 0.0111 | rpn_box_reg: 0.0010 |
# | epoch: 8 | Train loss: 7.3271 | classifier: 0.1679 | box_reg: 0.1519 | keypoint: 6.7153 | objectness: 0.0536 | rpn_box_reg: 0.0150 |
# | epoch: 8 | Train loss: 2.9266 | classifier: 0.0212 | box_reg: 0.0211 | keypoint: 2.6545 | objectness: 0.0027 | rpn_box_reg: 0.0038 |
# | epoch: 8 | Train loss: 4.5465 | classifier: 0.0390 | box_reg: 0.0246 | keypoint: 4.1763 | objectness: 0.0228 | rpn_box_reg: 0.0606 |
# | epoch: 8 | Train loss: 4.2863 | classifier: 0.0741 | box_reg: 0.1120 | keypoint: 3.8561 | objectness: 0.0180 | rpn_box_reg: 0.0027 |
# | epoch: 8 | Train loss: 4.3649 | classifier: 0.0260 | box_reg: 0.0362 | keypoint: 4.0732 | objectness: 0.0043 | rpn_box_reg: 0.0019 |
# | epoch: 8 | Train loss: 7.3483 | classifier: 0.1115 | box_reg: 0.1074 | keypoint: 6.8659 | objectness: 0.0319 | rpn_box_reg: 0.0083 |
# | epoch: 8 | Train loss: 3.8502 | classifier: 0.0445 | box_reg: 0.0417 | keypoint: 3.5209 | objectness: 0.0081 | rpn_box_reg: 0.0117 |
# | epoch: 8 | Train loss: 5.3458 | classifier: 0.0547 | box_reg: 0.0684 | keypoint: 4.8290 | objectness: 0.0260 | rpn_box_reg: 0.1445 |
# | epoch: 8 | Train loss: 5.7291 | classifier: 0.0893 | box_reg: 0.0776 | keypoint: 5.2988 | objectness: 0.0251 | rpn_box_reg: 0.0150 |
# | epoch: 8 | Train loss: 3.7250 | classifier: 0.0310 | box_reg: 0.0343 | keypoint: 3.3757 | objectness: 0.0165 | rpn_box_reg: 0.0443 |
# | epoch: 8 | Train loss: 2.3730 | classifier: 0.0293 | box_reg: 0.0313 | keypoint: 2.0804 | objectness: 0.0037 | rpn_box_reg: 0.0050 |
# | epoch: 8 | Train loss: 6.0945 | classifier: 0.0457 | box_reg: 0.0450 | keypoint: 5.7090 | objectness: 0.0273 | rpn_box_reg: 0.0442 |
# | epoch: 8 | Train loss: 4.3924 | classifier: 0.0193 | box_reg: 0.0426 | keypoint: 4.0888 | objectness: 0.0147 | rpn_box_reg: 0.0037 |
# | epoch: 8 | Train loss: 3.2870 | classifier: 0.0632 | box_reg: 0.0785 | keypoint: 2.6149 | objectness: 0.0548 | rpn_box_reg: 0.2524 |
# | epoch: 8 | Train loss: 2.7537 | classifier: 0.0249 | box_reg: 0.0370 | keypoint: 2.4528 | objectness: 0.0130 | rpn_box_reg: 0.0027 |
# | epoch: 8 | Train loss: 4.5141 | classifier: 0.0769 | box_reg: 0.0692 | keypoint: 4.0665 | objectness: 0.0675 | rpn_box_reg: 0.0108 |
# | epoch: 8 | Train loss: 2.9593 | classifier: 0.0202 | box_reg: 0.0262 | keypoint: 2.6843 | objectness: 0.0011 | rpn_box_reg: 0.0043 |
# | epoch: 8 | Train loss: 5.4594 | classifier: 0.0521 | box_reg: 0.0616 | keypoint: 5.0729 | objectness: 0.0138 | rpn_box_reg: 0.0357 |
# | epoch: 8 | Train loss: 4.0241 | classifier: 0.0302 | box_reg: 0.0561 | keypoint: 3.7062 | objectness: 0.0019 | rpn_box_reg: 0.0065 |
# | epoch: 8 | Train loss: 2.7100 | classifier: 0.0122 | box_reg: 0.0172 | keypoint: 2.4561 | objectness: 0.0010 | rpn_box_reg: 0.0003 |
# | epoch: 8 | Train loss: 7.6859 | classifier: 0.1942 | box_reg: 0.1864 | keypoint: 6.9582 | objectness: 0.1004 | rpn_box_reg: 0.0235 |
# | epoch: 8 | Train loss: 5.1696 | classifier: 0.0845 | box_reg: 0.0930 | keypoint: 4.7392 | objectness: 0.0166 | rpn_box_reg: 0.0130 |
# | epoch: 8 | Train loss: 3.3293 | classifier: 0.0377 | box_reg: 0.0448 | keypoint: 3.0134 | objectness: 0.0056 | rpn_box_reg: 0.0046 |
# | epoch: 8 | Train loss: 2.2578 | classifier: 0.0311 | box_reg: 0.0547 | keypoint: 1.9450 | objectness: 0.0023 | rpn_box_reg: 0.0015 |
# | epoch: 8 | Train loss: 2.8984 | classifier: 0.0268 | box_reg: 0.0284 | keypoint: 2.6181 | objectness: 0.0007 | rpn_box_reg: 0.0013 |
# | epoch: 8 | Train loss: 3.7125 | classifier: 0.0218 | box_reg: 0.0436 | keypoint: 3.4022 | objectness: 0.0166 | rpn_box_reg: 0.0051 |
# | epoch: 8 | Train loss: 5.0736 | classifier: 0.0662 | box_reg: 0.0820 | keypoint: 4.6820 | objectness: 0.0155 | rpn_box_reg: 0.0046 |
# | epoch: 8 | Train loss: 4.5547 | classifier: 0.0608 | box_reg: 0.0637 | keypoint: 4.1770 | objectness: 0.0284 | rpn_box_reg: 0.0017 |
# | epoch: 8 | Train loss: 3.1203 | classifier: 0.0239 | box_reg: 0.0604 | keypoint: 2.7966 | objectness: 0.0119 | rpn_box_reg: 0.0042 |
# | epoch: 8 | Train loss: 8.0989 | classifier: 0.1984 | box_reg: 0.2531 | keypoint: 7.3642 | objectness: 0.0495 | rpn_box_reg: 0.0105 |
# | epoch: 8 | Train loss: 3.9647 | classifier: 0.0406 | box_reg: 0.0762 | keypoint: 3.6010 | objectness: 0.0095 | rpn_box_reg: 0.0142 |
# | epoch: 8 | Train loss: 3.9786 | classifier: 0.0520 | box_reg: 0.0516 | keypoint: 3.6397 | objectness: 0.0064 | rpn_box_reg: 0.0056 |
# | epoch: 8 | Train loss: 6.1674 | classifier: 0.0925 | box_reg: 0.1101 | keypoint: 5.7214 | objectness: 0.0151 | rpn_box_reg: 0.0052 |
# | epoch: 8 | Train loss: 5.5451 | classifier: 0.0792 | box_reg: 0.0932 | keypoint: 5.1382 | objectness: 0.0106 | rpn_box_reg: 0.0007 |
# | epoch: 8 | Train loss: 4.8803 | classifier: 0.1052 | box_reg: 0.1262 | keypoint: 4.3766 | objectness: 0.0477 | rpn_box_reg: 0.0013 |
# | epoch: 8 | Train loss: 4.8052 | classifier: 0.0681 | box_reg: 0.0758 | keypoint: 4.4175 | objectness: 0.0144 | rpn_box_reg: 0.0062 |
# | epoch: 8 | Train loss: 5.6795 | classifier: 0.1307 | box_reg: 0.1878 | keypoint: 5.1197 | objectness: 0.0122 | rpn_box_reg: 0.0058 |
# | epoch: 8 | Train loss: 7.5319 | classifier: 0.2080 | box_reg: 0.2338 | keypoint: 6.8424 | objectness: 0.0210 | rpn_box_reg: 0.0037 |
# | epoch: 8 | Train loss: 3.8789 | classifier: 0.0622 | box_reg: 0.0689 | keypoint: 3.2236 | objectness: 0.1352 | rpn_box_reg: 0.1659 |
# | epoch: 8 | Train loss: 2.4207 | classifier: 0.0184 | box_reg: 0.0140 | keypoint: 2.1631 | objectness: 0.0006 | rpn_box_reg: 0.0014 |
# | epoch: 8 | Train loss: 5.5181 | classifier: 0.0854 | box_reg: 0.0886 | keypoint: 5.1045 | objectness: 0.0145 | rpn_box_reg: 0.0020 |
# | epoch: 8 | Train loss: 7.8316 | classifier: 0.1490 | box_reg: 0.1547 | keypoint: 7.0822 | objectness: 0.0603 | rpn_box_reg: 0.1622 |
# | epoch: 8 | Train loss: 3.8764 | classifier: 0.0270 | box_reg: 0.0301 | keypoint: 3.5937 | objectness: 0.0009 | rpn_box_reg: 0.0015 |
# | epoch: 8 | Train loss: 3.1697 | classifier: 0.0397 | box_reg: 0.0581 | keypoint: 2.8431 | objectness: 0.0017 | rpn_box_reg: 0.0039 |
# | epoch: 8 | Train loss: 6.8196 | classifier: 0.1170 | box_reg: 0.1351 | keypoint: 6.3131 | objectness: 0.0245 | rpn_box_reg: 0.0067 |
# | epoch: 8 | Train loss: 5.8014 | classifier: 0.0669 | box_reg: 0.1103 | keypoint: 5.3868 | objectness: 0.0082 | rpn_box_reg: 0.0060 |
# | epoch: 8 | Train loss: 4.3514 | classifier: 0.0513 | box_reg: 0.0765 | keypoint: 3.9909 | objectness: 0.0056 | rpn_box_reg: 0.0039 |
# | epoch: 8 | Train loss: 5.0803 | classifier: 0.0387 | box_reg: 0.0627 | keypoint: 4.7431 | objectness: 0.0091 | rpn_box_reg: 0.0035 |
# | epoch: 8 | Train loss: 5.5009 | classifier: 0.0842 | box_reg: 0.0840 | keypoint: 5.0326 | objectness: 0.0563 | rpn_box_reg: 0.0206 |
# | epoch: 8 | Train loss: 5.8680 | classifier: 0.0807 | box_reg: 0.0756 | keypoint: 5.4590 | objectness: 0.0233 | rpn_box_reg: 0.0063 |
# | epoch: 8 | Train loss: 4.7312 | classifier: 0.0588 | box_reg: 0.0717 | keypoint: 4.3698 | objectness: 0.0071 | rpn_box_reg: 0.0007 |
# | epoch: 8 | Train loss: 4.5520 | classifier: 0.0384 | box_reg: 0.0539 | keypoint: 4.2321 | objectness: 0.0009 | rpn_box_reg: 0.0037 |
# | epoch: 8 | Train loss: 2.5398 | classifier: 0.0412 | box_reg: 0.0465 | keypoint: 2.2268 | objectness: 0.0005 | rpn_box_reg: 0.0016 |
# | epoch: 8 | Train loss: 4.5889 | classifier: 0.0785 | box_reg: 0.0885 | keypoint: 4.1695 | objectness: 0.0200 | rpn_box_reg: 0.0092 |
# | epoch: 8 | Train loss: 6.0204 | classifier: 0.0451 | box_reg: 0.0704 | keypoint: 5.6755 | objectness: 0.0038 | rpn_box_reg: 0.0025 |
# | epoch: 8 | Train loss: 2.6145 | classifier: 0.0319 | box_reg: 0.0530 | keypoint: 2.2994 | objectness: 0.0022 | rpn_box_reg: 0.0047 |
# | epoch: 8 | Train loss: 6.9062 | classifier: 0.1069 | box_reg: 0.1521 | keypoint: 6.4036 | objectness: 0.0125 | rpn_box_reg: 0.0081 |
# | epoch: 8 | Train loss: 4.7639 | classifier: 0.0617 | box_reg: 0.0652 | keypoint: 4.3993 | objectness: 0.0106 | rpn_box_reg: 0.0041 |
# | epoch: 8 | Train loss: 5.4074 | classifier: 0.0387 | box_reg: 0.0506 | keypoint: 5.0912 | objectness: 0.0017 | rpn_box_reg: 0.0020 |
# | epoch: 8 | Train loss: 2.5749 | classifier: 0.0219 | box_reg: 0.0252 | keypoint: 2.3014 | objectness: 0.0016 | rpn_box_reg: 0.0016 |
# | epoch: 8 | Train loss: 5.1942 | classifier: 0.0600 | box_reg: 0.0655 | keypoint: 4.8066 | objectness: 0.0251 | rpn_box_reg: 0.0138 |
# | epoch: 8 | Train loss: 4.7148 | classifier: 0.0628 | box_reg: 0.0629 | keypoint: 4.3451 | objectness: 0.0131 | rpn_box_reg: 0.0079 |
# | epoch: 8 | Train loss: 4.9010 | classifier: 0.0829 | box_reg: 0.1146 | keypoint: 4.4592 | objectness: 0.0142 | rpn_box_reg: 0.0070 |
# | epoch: 8 | Train loss: 4.4420 | classifier: 0.0894 | box_reg: 0.0911 | keypoint: 4.0164 | objectness: 0.0182 | rpn_box_reg: 0.0038 |

# %% [markdown]
# ## 예측

# %%
submission = pd.read_csv('./data/sample_submission.csv')
submission.head()
submission.shape

# %%
# submission file 
images_name = []
predicted = []
device = "cuda:0"

best_model.eval()
best_model.to(device)

path = './data/test_imgs/'
i=0
with torch.no_grad():
  for img_name in submission['image']:
    image = cv2.imread(path + img_name, cv2.COLOR_BGR2RGB)

    image = image / 255.0
    image = image.transpose(2, 0, 1)
    image = [torch.as_tensor(image, dtype=torch.float32, device=device)]

    Motionpreds = best_model(image)
    
    try : 
      Motionkeypoints = Motionpreds[0]['keypoints'].cpu().detach().numpy().copy()[0]
      
    except :
      print(img_name)
      print("predicted value is empty. \n")

    images_name.append(img_name)
    Motionkeypoints2 = Motionkeypoints[:, :2].copy()

    image = cv2.imread(path + img_name, cv2.COLOR_BGR2RGB)
    if i % 100 == 0 :
      print(i)
      draw_keypoints(image, Motionkeypoints2, [], edges)
    i=i+1

    motion_keypoints = [item for sublist in Motionkeypoints2 for item in sublist]
    #print(flat_keypoints)
    predicted.append(motion_keypoints)

# %%
print(len(predicted)) 
print(len(images_name))

# %%
sub = pd.DataFrame(columns=submission.columns)

all_predictions = np.array(predicted)
sub['image'] = images_name
sub.iloc[:,1:] = all_predictions

sub.to_csv('./code/5CV-hr/sub_5fold_0330_best.csv', index=False)
